# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gymnasium as gym
from PIL import Image

# %%
class QLearning:
    
    """
    Class of the Q-Learning algorithm. This is a ready class that discretises all dimensions of the state space.
    """
    
    def __init__(self, env, gamma=0.9):
        """
        Description
        --------------
        Constructor of class FrozenLakeAgent.
        
        Arguments
        --------------
        env          : gymnasium environment.
        gamma        : Float in [0, 1] generally close to 1, discount factor.
        n_states     : Int, the number of states.
        q_values     : np.array of shape (n_states, n_actions) or None, state-action values.
        """
        
        self.env = env
        self.gamma = gamma
        self.n_states = None
        self.n_actions = None

    def reset(self):
        """
        Description
        --------------
        Reinitialize the state value function, the state-action value function and the policy.

        Arguments
        --------------

        Returns
        --------------
        """

        self.q_values, self.visits = {}, {}
            
    def action_explore(self, state, epsilon):
        """
        Description
        --------------
        Take an action according to an epsilon-greedy policy.
        
        Arguments
        --------------
        state   : np.array, state.
        epsilon : Float in ]0, 1[, probability of taking a suboptimal action.
        
        Returns
        --------------
        Int, action to perform.
        """

        action_max = self.action(state)
        bern = np.random.binomial(1, 1 - epsilon)
        if bern == 1:
            return action_max
        
        return self.env.action_space.sample()
        
    def action(self, state):
        """
        Description
        --------------
        Take an action according to the estimated optimal policy.
        
        Arguments
        --------------
        state : Int, state.
        
        Returns
        --------------
        Int, estimated optimal action.
        """

        try:
            return self.q_values[state].argmax()
        
        except KeyError:
            return self.env.action_space.sample()
        
    def update_q_value(self, state, action, reward, next_state, alpha):
        """
        Description
        --------------
        Perform a q-learning update of experience (state, action, reward, next_state).
        
        Arguments
        --------------
        
        Returns
        --------------
        """

        try:
            q_max = self.q_values[next_state].max()

        except KeyError:
            self.q_values[next_state], self.visits[next_state] = np.zeros(self.n_actions), np.zeros(self.n_actions)
            q_max = 0

        try:
            td = reward + self.gamma*q_max - self.q_values[state][action]

        except KeyError:
            self.q_values[state], self.visits[state] = np.zeros(self.n_actions), np.zeros(self.n_actions)
            td = reward + self.gamma*q_max - self.q_values[state][action]
            
        self.visits[state][action] += 1
        if alpha is None:
            alpha = 1/(self.visits[state][action])

        self.q_values[state][action] += alpha*td
        
    def unroll(self, alpha, epsilon):
        """
        Description
        --------------
        Unroll the current epsilon-greedy policy from state and update the q-values at each step.
        
        Arguments
        --------------
        alpha   : Float in ]0, 1[, learning rate.
        epsilon : Float in ]0, 1[, parameter of the epsilon-greedy policy.
        
        Returns
        --------------
        """

        state, _ = self.env.reset()
        done = False
        while not done:
            action = self.action_explore(state, epsilon)
            next_state, reward, terminated, truncated, _ = self.env.step(action)
            done = (terminated or truncated)
            self.update_q_value(state, action, reward, next_state, alpha)
            state = next_state
            
    def train(self, alpha=0.1, epsilon_start=1, epsilon_stop=0.1, decay_rate=1e-3, n_train=1000, print_iter=10):
        """
        Description
        --------------
        Train an on-policy first-visit MC algorithm.
        
        Arguments
        --------------
        alpha         : Float in ]0, 1[, learning rate.
        epsilon_start : Float in ]0, 1[, initial value of epsilon.
        epsilon_stopt : Float in ]0, 1[, final value of epsilon.
        decay_rate    : Float, decay rate of epsilon from epsilon_start to epsilon_stop.
        n_train       : Int, total number of iterations.
        print_iter    : Int, number of iterations between two successive prints.
        
        Returns
        --------------
        """

        for i in range(n_train):
            epsilon = epsilon_stop + (epsilon_start - epsilon_stop)*np.exp(-decay_rate*i)
            self.unroll(alpha, epsilon)
            if i%print_iter == 0:
                print('Iteration : %d' %i)
                print('Epsilon   : %.5f' %epsilon)
                print('\n')
            
    def test(self, env, n_episodes=1000, verbose=False):
        """
        Description
        --------------
        Test the agent.
        
        Arguments
        --------------
        env        : gymnasium environment.
        n_episodes : Int, number of test episodes.
        verbose    : Boolean, if True, print the episode index and its corresponding length and return.
        
        Returns
        --------------
        """
        
        returns = np.empty(n_episodes)
        for episode in range(n_episodes):
            state, _ = env.reset()
            done = False
            R = 0
            n_steps = 0
            while not done:
                action = self.action(state)
                next_state, reward, terminated, truncated, _ = env.step(action)
                done = (terminated or truncated)
                state = next_state
                R += reward
                n_steps += 1
                
            returns[episode] = R
            if verbose:
                print('Episode : %d, length : %d, return : %.3F' %(episode, n_steps, R))

        return_avg, return_std = returns.mean(), returns.std()
        print('avg : %.3f, std : %.3f' %(return_avg, return_std))
        return return_avg, return_std
            
    def save_gif(self, env, file_name, n_episodes=1):
        """
        Description
        --------------
        Test the agent and save a gif.
        
        Arguments
        --------------
        env       : gymnasium environment.
        file_name : String, path to the saved gif.
        
        Returns
        --------------
        """
        
        frames = []
        for i in range(n_episodes):
            state, _ = env.reset()
            done = False
            R = 0
            n_steps = 0
            while not done:
                frames.append(Image.fromarray(env.render(), mode='RGB'))
                action = self.action(state)
                next_state, reward, terminated, truncated, _ = env.step(action)
                done = (terminated or truncated)
                state = next_state
                R += reward
                n_steps += 1

            frames.append(Image.fromarray(env.render(), mode='RGB'))
            
        frames[0].save(file_name, save_all=True, append_images=frames[1:], optimize=False, duration=150, loop=0)

# %%
class FrozenLakeQLearning(QLearning):
    """
    Description
    --------------
    Class describing an agent operating in the FrozenLake environment.
    """
    
    def __init__(self, env, gamma=0.9):
        """
        Description
        --------------
        Constructor of class FrozenLakeAgent.
        
        Arguments
        --------------
        env          : CliffWalking-v0 environment.
        gamma        : Float in [0, 1] generally close to 1, discount factor.
        n_states     : Int, the number of states.
        n_actions    : Int, the number of actions.
        q_values     : np.array of shape (n_states, n_actions) or None, q-values.
        """
        
        super(FrozenLakeQLearning, self).__init__(env, gamma)
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        self.reset()

class CliffWalkingQLearning(QLearning):
    """
    Description
    --------------
    Class describing an agent operating in the CliffWalking environment.
    """
    
    def __init__(self, env, gamma=0.9):
        """
        Description
        --------------
        Constructor of class FrozenLakeAgent.
        
        Arguments
        --------------
        env          : CliffWalking-v0 environment.
        gamma        : Float in [0, 1] generally close to 1, discount factor.
        n_states     : Int, the number of states.
        n_actions    : Int, the number of actions.
        q_values     : np.array of shape (n_states, n_actions) or None, q-values.
        """
        
        super(CliffWalkingQLearning, self).__init__(env, gamma)
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        self.reset()

class TaxiQLearning(QLearning):
    """
    Description
    --------------
    Class describing an agent operating in the Taxi environment.
    """
    
    def __init__(self, env, gamma=0.9):
        """
        Description
        --------------
        Constructor of class FrozenLakeAgent.
        
        Arguments
        --------------
        env          : CliffWalking-v0 environment.
        gamma        : Float in [0, 1] generally close to 1, discount factor.
        n_states     : Int, the number of states.
        n_actions    : Int, the number of actions.
        q_values     : np.array of shape (n_states, n_actions) or None, q-values.
        """
        
        super(TaxiQLearning, self).__init__(env, gamma)
        self.n_states = env.observation_space.n
        self.n_actions = env.action_space.n
        self.reset()

class BlackJackQLearning(QLearning):
    """
    Description
    --------------
    Class describing an agent operating in the BlackJack environment.
    """
    
    def __init__(self, env, gamma=0.9):
        """
        Description
        --------------
        Constructor of class FrozenLakeAgent.
        
        Arguments
        --------------
        env          : CliffWalking-v0 environment.
        gamma        : Float in [0, 1] generally close to 1, discount factor.
        n_states     : Int, the number of states.
        n_actions    : Int, the number of actions.
        q_values     : np.array of shape (n_states, n_actions) or None, q-values.
        """
        
        super(BlackJackQLearning, self).__init__(env, gamma)
        self.n_actions = env.action_space.n
        self.reset()

# %% [markdown]
# ## Frozen Lake

# %%
is_slippery = False
map_name = '8x8'

env = gym.make('FrozenLake-v1', is_slippery=is_slippery, map_name=map_name)
agent = FrozenLakeQLearning(env, gamma=0.99)
agent.train(alpha=0.1, n_train=100000, print_iter=1000, decay_rate=1e-4)
# Out:
# Iteration : 0
# Epsilon   : 1.00000
#
#
# Iteration : 1000
# Epsilon   : 0.91435
#
#
# Iteration : 2000
# Epsilon   : 0.83686
#
#
# Iteration : 3000
# Epsilon   : 0.76674
#
#
# Iteration : 4000
# Epsilon   : 0.70329
#
#
# Iteration : 5000
# Epsilon   : 0.64588
#
#
# Iteration : 6000
# Epsilon   : 0.59393
#
#
# Iteration : 7000
# Epsilon   : 0.54693
#
#
# Iteration : 8000
# Epsilon   : 0.50440
#
#
# Iteration : 9000
# Epsilon   : 0.46591
#
#
# Iteration : 10000
# Epsilon   : 0.43109
#
#
# Iteration : 11000
# Epsilon   : 0.39958
#
#
# Iteration : 12000
# Epsilon   : 0.37107
#
#
# Iteration : 13000
# Epsilon   : 0.34528
#
#
# Iteration : 14000
# Epsilon   : 0.32194
#
#
# Iteration : 15000
# Epsilon   : 0.30082
#
#
# Iteration : 16000
# Epsilon   : 0.28171
#
#
# Iteration : 17000
# Epsilon   : 0.26442
#
#
# Iteration : 18000
# Epsilon   : 0.24877
#
#
# Iteration : 19000
# Epsilon   : 0.23461
#
#
# Iteration : 20000
# Epsilon   : 0.22180
#
#
# Iteration : 21000
# Epsilon   : 0.21021
#
#
# Iteration : 22000
# Epsilon   : 0.19972
#
#
# Iteration : 23000
# Epsilon   : 0.19023
#
#
# Iteration : 24000
# Epsilon   : 0.18165
#
#
# Iteration : 25000
# Epsilon   : 0.17388
#
#
# Iteration : 26000
# Epsilon   : 0.16685
#
#
# Iteration : 27000
# Epsilon   : 0.16048
#
#
# Iteration : 28000
# Epsilon   : 0.15473
#
#
# Iteration : 29000
# Epsilon   : 0.14952
#
#
# Iteration : 30000
# Epsilon   : 0.14481
#
#
# Iteration : 31000
# Epsilon   : 0.14054
#
#
# Iteration : 32000
# Epsilon   : 0.13669
#
#
# Iteration : 33000
# Epsilon   : 0.13319
#
#
# Iteration : 34000
# Epsilon   : 0.13004
#
#
# Iteration : 35000
# Epsilon   : 0.12718
#
#
# Iteration : 36000
# Epsilon   : 0.12459
#
#
# Iteration : 37000
# Epsilon   : 0.12225
#
#
# Iteration : 38000
# Epsilon   : 0.12013
#
#
# Iteration : 39000
# Epsilon   : 0.11822
#
#
# Iteration : 40000
# Epsilon   : 0.11648
#
#
# Iteration : 41000
# Epsilon   : 0.11492
#
#
# Iteration : 42000
# Epsilon   : 0.11350
#
#
# Iteration : 43000
# Epsilon   : 0.11221
#
#
# Iteration : 44000
# Epsilon   : 0.11105
#
#
# Iteration : 45000
# Epsilon   : 0.11000
#
#
# Iteration : 46000
# Epsilon   : 0.10905
#
#
# Iteration : 47000
# Epsilon   : 0.10819
#
#
# Iteration : 48000
# Epsilon   : 0.10741
#
#
# Iteration : 49000
# Epsilon   : 0.10670
#
#
# Iteration : 50000
# Epsilon   : 0.10606
#
#
# Iteration : 51000
# Epsilon   : 0.10549
#
#
# Iteration : 52000
# Epsilon   : 0.10496
#
#
# Iteration : 53000
# Epsilon   : 0.10449
#
#
# Iteration : 54000
# Epsilon   : 0.10406
#
#
# Iteration : 55000
# Epsilon   : 0.10368
#
#
# Iteration : 56000
# Epsilon   : 0.10333
#
#
# Iteration : 57000
# Epsilon   : 0.10301
#
#
# Iteration : 58000
# Epsilon   : 0.10272
#
#
# Iteration : 59000
# Epsilon   : 0.10247
#
#
# Iteration : 60000
# Epsilon   : 0.10223
#
#
# Iteration : 61000
# Epsilon   : 0.10202
#
#
# Iteration : 62000
# Epsilon   : 0.10183
#
#
# Iteration : 63000
# Epsilon   : 0.10165
#
#
# Iteration : 64000
# Epsilon   : 0.10150
#
#
# Iteration : 65000
# Epsilon   : 0.10135
#
#
# Iteration : 66000
# Epsilon   : 0.10122
#
#
# Iteration : 67000
# Epsilon   : 0.10111
#
#
# Iteration : 68000
# Epsilon   : 0.10100
#
#
# Iteration : 69000
# Epsilon   : 0.10091
#
#
# Iteration : 70000
# Epsilon   : 0.10082
#
#
# Iteration : 71000
# Epsilon   : 0.10074
#
#
# Iteration : 72000
# Epsilon   : 0.10067
#
#
# Iteration : 73000
# Epsilon   : 0.10061
#
#
# Iteration : 74000
# Epsilon   : 0.10055
#
#
# Iteration : 75000
# Epsilon   : 0.10050
#
#
# Iteration : 76000
# Epsilon   : 0.10045
#
#
# Iteration : 77000
# Epsilon   : 0.10041
#
#
# Iteration : 78000
# Epsilon   : 0.10037
#
#
# Iteration : 79000
# Epsilon   : 0.10033
#
#
# Iteration : 80000
# Epsilon   : 0.10030
#
#
# Iteration : 81000
# Epsilon   : 0.10027
#
#
# Iteration : 82000
# Epsilon   : 0.10025
#
#
# Iteration : 83000
# Epsilon   : 0.10022
#
#
# Iteration : 84000
# Epsilon   : 0.10020
#
#
# Iteration : 85000
# Epsilon   : 0.10018
#
#
# Iteration : 86000
# Epsilon   : 0.10017
#
#
# Iteration : 87000
# Epsilon   : 0.10015
#
#
# Iteration : 88000
# Epsilon   : 0.10014
#
#
# Iteration : 89000
# Epsilon   : 0.10012
#
#
# Iteration : 90000
# Epsilon   : 0.10011
#
#
# Iteration : 91000
# Epsilon   : 0.10010
#
#
# Iteration : 92000
# Epsilon   : 0.10009
#
#
# Iteration : 93000
# Epsilon   : 0.10008
#
#
# Iteration : 94000
# Epsilon   : 0.10007
#
#
# Iteration : 95000
# Epsilon   : 0.10007
#
#
# Iteration : 96000
# Epsilon   : 0.10006
#
#
# Iteration : 97000
# Epsilon   : 0.10006
#
#
# Iteration : 98000
# Epsilon   : 0.10005
#
#
# Iteration : 99000
# Epsilon   : 0.10005

# %%
agent.test(env, n_episodes=100, verbose=True)
# Out:
# Episode : 0, length : 14, return : 1.000
# Episode : 1, length : 14, return : 1.000
# Episode : 2, length : 14, return : 1.000
# Episode : 3, length : 14, return : 1.000
# Episode : 4, length : 14, return : 1.000
# Episode : 5, length : 14, return : 1.000
# Episode : 6, length : 14, return : 1.000
# Episode : 7, length : 14, return : 1.000
# Episode : 8, length : 14, return : 1.000
# Episode : 9, length : 14, return : 1.000
# Episode : 10, length : 14, return : 1.000
# Episode : 11, length : 14, return : 1.000
# Episode : 12, length : 14, return : 1.000
# Episode : 13, length : 14, return : 1.000
# Episode : 14, length : 14, return : 1.000
# Episode : 15, length : 14, return : 1.000
# Episode : 16, length : 14, return : 1.000
# Episode : 17, length : 14, return : 1.000
# Episode : 18, length : 14, return : 1.000
# Episode : 19, length : 14, return : 1.000
# Episode : 20, length : 14, return : 1.000
# Episode : 21, length : 14, return : 1.000
# Episode : 22, length : 14, return : 1.000
# Episode : 23, length : 14, return : 1.000
# Episode : 24, length : 14, return : 1.000
# Episode : 25, length : 14, return : 1.000
# Episode : 26, length : 14, return : 1.000
# Episode : 27, length : 14, return : 1.000
# Episode : 28, length : 14, return : 1.000
# Episode : 29, length : 14, return : 1.000
# Episode : 30, length : 14, return : 1.000
# Episode : 31, length : 14, return : 1.000
# Episode : 32, length : 14, return : 1.000
# Episode : 33, length : 14, return : 1.000
# Episode : 34, length : 14, return : 1.000
# Episode : 35, length : 14, return : 1.000
# Episode : 36, length : 14, return : 1.000
# Episode : 37, length : 14, return : 1.000
# Episode : 38, length : 14, return : 1.000
# Episode : 39, length : 14, return : 1.000
# Episode : 40, length : 14, return : 1.000
# Episode : 41, length : 14, return : 1.000
# Episode : 42, length : 14, return : 1.000
# Episode : 43, length : 14, return : 1.000
# Episode : 44, length : 14, return : 1.000
# Episode : 45, length : 14, return : 1.000
# Episode : 46, length : 14, return : 1.000
# Episode : 47, length : 14, return : 1.000
# Episode : 48, length : 14, return : 1.000
# Episode : 49, length : 14, return : 1.000
# Episode : 50, length : 14, return : 1.000
# Episode : 51, length : 14, return : 1.000
# Episode : 52, length : 14, return : 1.000
# Episode : 53, length : 14, return : 1.000
# Episode : 54, length : 14, return : 1.000
# Episode : 55, length : 14, return : 1.000
# Episode : 56, length : 14, return : 1.000
# Episode : 57, length : 14, return : 1.000
# Episode : 58, length : 14, return : 1.000
# Episode : 59, length : 14, return : 1.000
# Episode : 60, length : 14, return : 1.000
# Episode : 61, length : 14, return : 1.000
# Episode : 62, length : 14, return : 1.000
# Episode : 63, length : 14, return : 1.000
# Episode : 64, length : 14, return : 1.000
# Episode : 65, length : 14, return : 1.000
# Episode : 66, length : 14, return : 1.000
# Episode : 67, length : 14, return : 1.000
# Episode : 68, length : 14, return : 1.000
# Episode : 69, length : 14, return : 1.000
# Episode : 70, length : 14, return : 1.000
# Episode : 71, length : 14, return : 1.000
# Episode : 72, length : 14, return : 1.000
# Episode : 73, length : 14, return : 1.000
# Episode : 74, length : 14, return : 1.000
# Episode : 75, length : 14, return : 1.000
# Episode : 76, length : 14, return : 1.000
# Episode : 77, length : 14, return : 1.000
# Episode : 78, length : 14, return : 1.000
# Episode : 79, length : 14, return : 1.000
# Episode : 80, length : 14, return : 1.000
# Episode : 81, length : 14, return : 1.000
# Episode : 82, length : 14, return : 1.000
# Episode : 83, length : 14, return : 1.000
# Episode : 84, length : 14, return : 1.000
# Episode : 85, length : 14, return : 1.000
# Episode : 86, length : 14, return : 1.000
# Episode : 87, length : 14, return : 1.000
# Episode : 88, length : 14, return : 1.000
# Episode : 89, length : 14, return : 1.000
# Episode : 90, length : 14, return : 1.000
# Episode : 91, length : 14, return : 1.000
# Episode : 92, length : 14, return : 1.000
# Episode : 93, length : 14, return : 1.000
# Episode : 94, length : 14, return : 1.000
# Episode : 95, length : 14, return : 1.000
# Episode : 96, length : 14, return : 1.000
# Episode : 97, length : 14, return : 1.000
# Episode : 98, length : 14, return : 1.000
# Episode : 99, length : 14, return : 1.000
# avg : 1.000, std : 0.000
# (1.0, 0.0)

# %%
env = gym.make('FrozenLake-v1', is_slippery=is_slippery, map_name=map_name, render_mode='human')
agent.test(env, n_episodes=5, verbose=True)
env.close()
# Out:
# 2025-03-31 23:05:04.099 python[5297:395631] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-31 23:05:04.099 python[5297:395631] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Episode : 0, length : 14, return : 1.000
# Episode : 1, length : 14, return : 1.000
# Episode : 2, length : 14, return : 1.000
# Episode : 3, length : 14, return : 1.000
# Episode : 4, length : 14, return : 1.000
# avg : 1.000, std : 0.000

# %% [markdown]
# ## Cliff Walking

# %%
env = gym.make('CliffWalking-v0', max_episode_steps=100)
agent = CliffWalkingQLearning(env, gamma=0.99)
agent.train(alpha=0.1, n_train=100000, print_iter=1000, decay_rate=1e-4)
# Out:
# Iteration : 0
# Epsilon   : 1.00000
#
#
# Iteration : 1000
# Epsilon   : 0.91435
#
#
# Iteration : 2000
# Epsilon   : 0.83686
#
#
# Iteration : 3000
# Epsilon   : 0.76674
#
#
# Iteration : 4000
# Epsilon   : 0.70329
#
#
# Iteration : 5000
# Epsilon   : 0.64588
#
#
# Iteration : 6000
# Epsilon   : 0.59393
#
#
# Iteration : 7000
# Epsilon   : 0.54693
#
#
# Iteration : 8000
# Epsilon   : 0.50440
#
#
# Iteration : 9000
# Epsilon   : 0.46591
#
#
# Iteration : 10000
# Epsilon   : 0.43109
#
#
# Iteration : 11000
# Epsilon   : 0.39958
#
#
# Iteration : 12000
# Epsilon   : 0.37107
#
#
# Iteration : 13000
# Epsilon   : 0.34528
#
#
# Iteration : 14000
# Epsilon   : 0.32194
#
#
# Iteration : 15000
# Epsilon   : 0.30082
#
#
# Iteration : 16000
# Epsilon   : 0.28171
#
#
# Iteration : 17000
# Epsilon   : 0.26442
#
#
# Iteration : 18000
# Epsilon   : 0.24877
#
#
# Iteration : 19000
# Epsilon   : 0.23461
#
#
# Iteration : 20000
# Epsilon   : 0.22180
#
#
# Iteration : 21000
# Epsilon   : 0.21021
#
#
# Iteration : 22000
# Epsilon   : 0.19972
#
#
# Iteration : 23000
# Epsilon   : 0.19023
#
#
# Iteration : 24000
# Epsilon   : 0.18165
#
#
# Iteration : 25000
# Epsilon   : 0.17388
#
#
# Iteration : 26000
# Epsilon   : 0.16685
#
#
# Iteration : 27000
# Epsilon   : 0.16048
#
#
# Iteration : 28000
# Epsilon   : 0.15473
#
#
# Iteration : 29000
# Epsilon   : 0.14952
#
#
# Iteration : 30000
# Epsilon   : 0.14481
#
#
# Iteration : 31000
# Epsilon   : 0.14054
#
#
# Iteration : 32000
# Epsilon   : 0.13669
#
#
# Iteration : 33000
# Epsilon   : 0.13319
#
#
# Iteration : 34000
# Epsilon   : 0.13004
#
#
# Iteration : 35000
# Epsilon   : 0.12718
#
#
# Iteration : 36000
# Epsilon   : 0.12459
#
#
# Iteration : 37000
# Epsilon   : 0.12225
#
#
# Iteration : 38000
# Epsilon   : 0.12013
#
#
# Iteration : 39000
# Epsilon   : 0.11822
#
#
# Iteration : 40000
# Epsilon   : 0.11648
#
#
# Iteration : 41000
# Epsilon   : 0.11492
#
#
# Iteration : 42000
# Epsilon   : 0.11350
#
#
# Iteration : 43000
# Epsilon   : 0.11221
#
#
# Iteration : 44000
# Epsilon   : 0.11105
#
#
# Iteration : 45000
# Epsilon   : 0.11000
#
#
# Iteration : 46000
# Epsilon   : 0.10905
#
#
# Iteration : 47000
# Epsilon   : 0.10819
#
#
# Iteration : 48000
# Epsilon   : 0.10741
#
#
# Iteration : 49000
# Epsilon   : 0.10670
#
#
# Iteration : 50000
# Epsilon   : 0.10606
#
#
# Iteration : 51000
# Epsilon   : 0.10549
#
#
# Iteration : 52000
# Epsilon   : 0.10496
#
#
# Iteration : 53000
# Epsilon   : 0.10449
#
#
# Iteration : 54000
# Epsilon   : 0.10406
#
#
# Iteration : 55000
# Epsilon   : 0.10368
#
#
# Iteration : 56000
# Epsilon   : 0.10333
#
#
# Iteration : 57000
# Epsilon   : 0.10301
#
#
# Iteration : 58000
# Epsilon   : 0.10272
#
#
# Iteration : 59000
# Epsilon   : 0.10247
#
#
# Iteration : 60000
# Epsilon   : 0.10223
#
#
# Iteration : 61000
# Epsilon   : 0.10202
#
#
# Iteration : 62000
# Epsilon   : 0.10183
#
#
# Iteration : 63000
# Epsilon   : 0.10165
#
#
# Iteration : 64000
# Epsilon   : 0.10150
#
#
# Iteration : 65000
# Epsilon   : 0.10135
#
#
# Iteration : 66000
# Epsilon   : 0.10122
#
#
# Iteration : 67000
# Epsilon   : 0.10111
#
#
# Iteration : 68000
# Epsilon   : 0.10100
#
#
# Iteration : 69000
# Epsilon   : 0.10091
#
#
# Iteration : 70000
# Epsilon   : 0.10082
#
#
# Iteration : 71000
# Epsilon   : 0.10074
#
#
# Iteration : 72000
# Epsilon   : 0.10067
#
#
# Iteration : 73000
# Epsilon   : 0.10061
#
#
# Iteration : 74000
# Epsilon   : 0.10055
#
#
# Iteration : 75000
# Epsilon   : 0.10050
#
#
# Iteration : 76000
# Epsilon   : 0.10045
#
#
# Iteration : 77000
# Epsilon   : 0.10041
#
#
# Iteration : 78000
# Epsilon   : 0.10037
#
#
# Iteration : 79000
# Epsilon   : 0.10033
#
#
# Iteration : 80000
# Epsilon   : 0.10030
#
#
# Iteration : 81000
# Epsilon   : 0.10027
#
#
# Iteration : 82000
# Epsilon   : 0.10025
#
#
# Iteration : 83000
# Epsilon   : 0.10022
#
#
# Iteration : 84000
# Epsilon   : 0.10020
#
#
# Iteration : 85000
# Epsilon   : 0.10018
#
#
# Iteration : 86000
# Epsilon   : 0.10017
#
#
# Iteration : 87000
# Epsilon   : 0.10015
#
#
# Iteration : 88000
# Epsilon   : 0.10014
#
#
# Iteration : 89000
# Epsilon   : 0.10012
#
#
# Iteration : 90000
# Epsilon   : 0.10011
#
#
# Iteration : 91000
# Epsilon   : 0.10010
#
#
# Iteration : 92000
# Epsilon   : 0.10009
#
#
# Iteration : 93000
# Epsilon   : 0.10008
#
#
# Iteration : 94000
# Epsilon   : 0.10007
#
#
# Iteration : 95000
# Epsilon   : 0.10007
#
#
# Iteration : 96000
# Epsilon   : 0.10006
#
#
# Iteration : 97000
# Epsilon   : 0.10006
#
#
# Iteration : 98000
# Epsilon   : 0.10005
#
#
# Iteration : 99000
# Epsilon   : 0.10005

# %%
agent.test(env, n_episodes=100, verbose=True)
# Out:
# Episode : 0, length : 13, return : -13.000
# Episode : 1, length : 13, return : -13.000
# Episode : 2, length : 13, return : -13.000
# Episode : 3, length : 13, return : -13.000
# Episode : 4, length : 13, return : -13.000
# Episode : 5, length : 13, return : -13.000
# Episode : 6, length : 13, return : -13.000
# Episode : 7, length : 13, return : -13.000
# Episode : 8, length : 13, return : -13.000
# Episode : 9, length : 13, return : -13.000
# Episode : 10, length : 13, return : -13.000
# Episode : 11, length : 13, return : -13.000
# Episode : 12, length : 13, return : -13.000
# Episode : 13, length : 13, return : -13.000
# Episode : 14, length : 13, return : -13.000
# Episode : 15, length : 13, return : -13.000
# Episode : 16, length : 13, return : -13.000
# Episode : 17, length : 13, return : -13.000
# Episode : 18, length : 13, return : -13.000
# Episode : 19, length : 13, return : -13.000
# Episode : 20, length : 13, return : -13.000
# Episode : 21, length : 13, return : -13.000
# Episode : 22, length : 13, return : -13.000
# Episode : 23, length : 13, return : -13.000
# Episode : 24, length : 13, return : -13.000
# Episode : 25, length : 13, return : -13.000
# Episode : 26, length : 13, return : -13.000
# Episode : 27, length : 13, return : -13.000
# Episode : 28, length : 13, return : -13.000
# Episode : 29, length : 13, return : -13.000
# Episode : 30, length : 13, return : -13.000
# Episode : 31, length : 13, return : -13.000
# Episode : 32, length : 13, return : -13.000
# Episode : 33, length : 13, return : -13.000
# Episode : 34, length : 13, return : -13.000
# Episode : 35, length : 13, return : -13.000
# Episode : 36, length : 13, return : -13.000
# Episode : 37, length : 13, return : -13.000
# Episode : 38, length : 13, return : -13.000
# Episode : 39, length : 13, return : -13.000
# Episode : 40, length : 13, return : -13.000
# Episode : 41, length : 13, return : -13.000
# Episode : 42, length : 13, return : -13.000
# Episode : 43, length : 13, return : -13.000
# Episode : 44, length : 13, return : -13.000
# Episode : 45, length : 13, return : -13.000
# Episode : 46, length : 13, return : -13.000
# Episode : 47, length : 13, return : -13.000
# Episode : 48, length : 13, return : -13.000
# Episode : 49, length : 13, return : -13.000
# Episode : 50, length : 13, return : -13.000
# Episode : 51, length : 13, return : -13.000
# Episode : 52, length : 13, return : -13.000
# Episode : 53, length : 13, return : -13.000
# Episode : 54, length : 13, return : -13.000
# Episode : 55, length : 13, return : -13.000
# Episode : 56, length : 13, return : -13.000
# Episode : 57, length : 13, return : -13.000
# Episode : 58, length : 13, return : -13.000
# Episode : 59, length : 13, return : -13.000
# Episode : 60, length : 13, return : -13.000
# Episode : 61, length : 13, return : -13.000
# Episode : 62, length : 13, return : -13.000
# Episode : 63, length : 13, return : -13.000
# Episode : 64, length : 13, return : -13.000
# Episode : 65, length : 13, return : -13.000
# Episode : 66, length : 13, return : -13.000
# Episode : 67, length : 13, return : -13.000
# Episode : 68, length : 13, return : -13.000
# Episode : 69, length : 13, return : -13.000
# Episode : 70, length : 13, return : -13.000
# Episode : 71, length : 13, return : -13.000
# Episode : 72, length : 13, return : -13.000
# Episode : 73, length : 13, return : -13.000
# Episode : 74, length : 13, return : -13.000
# Episode : 75, length : 13, return : -13.000
# Episode : 76, length : 13, return : -13.000
# Episode : 77, length : 13, return : -13.000
# Episode : 78, length : 13, return : -13.000
# Episode : 79, length : 13, return : -13.000
# Episode : 80, length : 13, return : -13.000
# Episode : 81, length : 13, return : -13.000
# Episode : 82, length : 13, return : -13.000
# Episode : 83, length : 13, return : -13.000
# Episode : 84, length : 13, return : -13.000
# Episode : 85, length : 13, return : -13.000
# Episode : 86, length : 13, return : -13.000
# Episode : 87, length : 13, return : -13.000
# Episode : 88, length : 13, return : -13.000
# Episode : 89, length : 13, return : -13.000
# Episode : 90, length : 13, return : -13.000
# Episode : 91, length : 13, return : -13.000
# Episode : 92, length : 13, return : -13.000
# Episode : 93, length : 13, return : -13.000
# Episode : 94, length : 13, return : -13.000
# Episode : 95, length : 13, return : -13.000
# Episode : 96, length : 13, return : -13.000
# Episode : 97, length : 13, return : -13.000
# Episode : 98, length : 13, return : -13.000
# Episode : 99, length : 13, return : -13.000
# avg : -13.000, std : 0.000
# (-13.0, 0.0)

# %%
env = gym.make('CliffWalking-v0', max_episode_steps=100, render_mode='human')
agent.test(env, n_episodes=5, verbose=True)
env.close()
# Out:
# 2025-03-31 22:43:08.077 python[4781:376453] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-31 22:43:08.077 python[4781:376453] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Episode : 0, length : 13, return : -13.000
# Episode : 1, length : 13, return : -13.000
# Episode : 2, length : 13, return : -13.000
# Episode : 3, length : 13, return : -13.000
# Episode : 4, length : 13, return : -13.000
# avg : -13.000, std : 0.000

# %% [markdown]
# ## BlackJack

# %%
env = gym.make('Blackjack-v1', natural=False, sab=True)
agent = BlackJackQLearning(env, gamma=0.99)
agent.train(alpha=0.1, n_train=100000, print_iter=1000, decay_rate=1e-4)
# Out:
# Iteration : 0
# Epsilon   : 1.00000
#
#
# Iteration : 10000
# Epsilon   : 0.91435
#
#
# Iteration : 20000
# Epsilon   : 0.83686
#
#
# Iteration : 30000
# Epsilon   : 0.76674
#
#
# Iteration : 40000
# Epsilon   : 0.70329
#
#
# Iteration : 50000
# Epsilon   : 0.64588
#
#
# Iteration : 60000
# Epsilon   : 0.59393
#
#
# Iteration : 70000
# Epsilon   : 0.54693
#
#
# Iteration : 80000
# Epsilon   : 0.50440
#
#
# Iteration : 90000
# Epsilon   : 0.46591
#
#
# Iteration : 100000
# Epsilon   : 0.43109
#
#
# Iteration : 110000
# Epsilon   : 0.39958
#
#
# Iteration : 120000
# Epsilon   : 0.37107
#
#
# Iteration : 130000
# Epsilon   : 0.34528
#
#
# Iteration : 140000
# Epsilon   : 0.32194
#
#
# Iteration : 150000
# Epsilon   : 0.30082
#
#
# Iteration : 160000
# Epsilon   : 0.28171
#
#
# Iteration : 170000
# Epsilon   : 0.26442
#
#
# Iteration : 180000
# Epsilon   : 0.24877
#
#
# Iteration : 190000
# Epsilon   : 0.23461
#
#
# Iteration : 200000
# Epsilon   : 0.22180
#
#
# Iteration : 210000
# Epsilon   : 0.21021
#
#
# Iteration : 220000
# Epsilon   : 0.19972
#
#
# Iteration : 230000
# Epsilon   : 0.19023
#
#
# Iteration : 240000
# Epsilon   : 0.18165
#
#
# Iteration : 250000
# Epsilon   : 0.17388
#
#
# Iteration : 260000
# Epsilon   : 0.16685
#
#
# Iteration : 270000
# Epsilon   : 0.16048
#
#
# Iteration : 280000
# Epsilon   : 0.15473
#
#
# Iteration : 290000
# Epsilon   : 0.14952
#
#
# Iteration : 300000
# Epsilon   : 0.14481
#
#
# Iteration : 310000
# Epsilon   : 0.14054
#
#
# Iteration : 320000
# Epsilon   : 0.13669
#
#
# Iteration : 330000
# Epsilon   : 0.13319
#
#
# Iteration : 340000
# Epsilon   : 0.13004
#
#
# Iteration : 350000
# Epsilon   : 0.12718
#
#
# Iteration : 360000
# Epsilon   : 0.12459
#
#
# Iteration : 370000
# Epsilon   : 0.12225
#
#
# Iteration : 380000
# Epsilon   : 0.12013
#
#
# Iteration : 390000
# Epsilon   : 0.11822
#
#
# Iteration : 400000
# Epsilon   : 0.11648
#
#
# Iteration : 410000
# Epsilon   : 0.11492
#
#
# Iteration : 420000
# Epsilon   : 0.11350
#
#
# Iteration : 430000
# Epsilon   : 0.11221
#
#
# Iteration : 440000
# Epsilon   : 0.11105
#
#
# Iteration : 450000
# Epsilon   : 0.11000
#
#
# Iteration : 460000
# Epsilon   : 0.10905
#
#
# Iteration : 470000
# Epsilon   : 0.10819
#
#
# Iteration : 480000
# Epsilon   : 0.10741
#
#
# Iteration : 490000
# Epsilon   : 0.10670
#
#
# Iteration : 500000
# Epsilon   : 0.10606
#
#
# Iteration : 510000
# Epsilon   : 0.10549
#
#
# Iteration : 520000
# Epsilon   : 0.10496
#
#
# Iteration : 530000
# Epsilon   : 0.10449
#
#
# Iteration : 540000
# Epsilon   : 0.10406
#
#
# Iteration : 550000
# Epsilon   : 0.10368
#
#
# Iteration : 560000
# Epsilon   : 0.10333
#
#
# Iteration : 570000
# Epsilon   : 0.10301
#
#
# Iteration : 580000
# Epsilon   : 0.10272
#
#
# Iteration : 590000
# Epsilon   : 0.10247
#
#
# Iteration : 600000
# Epsilon   : 0.10223
#
#
# Iteration : 610000
# Epsilon   : 0.10202
#
#
# Iteration : 620000
# Epsilon   : 0.10183
#
#
# Iteration : 630000
# Epsilon   : 0.10165
#
#
# Iteration : 640000
# Epsilon   : 0.10150
#
#
# Iteration : 650000
# Epsilon   : 0.10135
#
#
# Iteration : 660000
# Epsilon   : 0.10122
#
#
# Iteration : 670000
# Epsilon   : 0.10111
#
#
# Iteration : 680000
# Epsilon   : 0.10100
#
#
# Iteration : 690000
# Epsilon   : 0.10091
#
#
# Iteration : 700000
# Epsilon   : 0.10082
#
#
# Iteration : 710000
# Epsilon   : 0.10074
#
#
# Iteration : 720000
# Epsilon   : 0.10067
#
#
# Iteration : 730000
# Epsilon   : 0.10061
#
#
# Iteration : 740000
# Epsilon   : 0.10055
#
#
# Iteration : 750000
# Epsilon   : 0.10050
#
#
# Iteration : 760000
# Epsilon   : 0.10045
#
#
# Iteration : 770000
# Epsilon   : 0.10041
#
#
# Iteration : 780000
# Epsilon   : 0.10037
#
#
# Iteration : 790000
# Epsilon   : 0.10033
#
#
# Iteration : 800000
# Epsilon   : 0.10030
#
#
# Iteration : 810000
# Epsilon   : 0.10027
#
#
# Iteration : 820000
# Epsilon   : 0.10025
#
#
# Iteration : 830000
# Epsilon   : 0.10022
#
#
# Iteration : 840000
# Epsilon   : 0.10020
#
#
# Iteration : 850000
# Epsilon   : 0.10018
#
#
# Iteration : 860000
# Epsilon   : 0.10017
#
#
# Iteration : 870000
# Epsilon   : 0.10015
#
#
# Iteration : 880000
# Epsilon   : 0.10014
#
#
# Iteration : 890000
# Epsilon   : 0.10012
#
#
# Iteration : 900000
# Epsilon   : 0.10011
#
#
# Iteration : 910000
# Epsilon   : 0.10010
#
#
# Iteration : 920000
# Epsilon   : 0.10009
#
#
# Iteration : 930000
# Epsilon   : 0.10008
#
#
# Iteration : 940000
# Epsilon   : 0.10007
#
#
# Iteration : 950000
# Epsilon   : 0.10007
#
#
# Iteration : 960000
# Epsilon   : 0.10006
#
#
# Iteration : 970000
# Epsilon   : 0.10006
#
#
# Iteration : 980000
# Epsilon   : 0.10005
#
#
# Iteration : 990000
# Epsilon   : 0.10005

# %%
agent.test(env, n_episodes=10000, verbose=True)
# Out:
# Episode : 0, length : 1, return : 1.000
# Episode : 1, length : 1, return : 0.000
# Episode : 2, length : 1, return : 1.000
# Episode : 3, length : 2, return : -1.000
# Episode : 4, length : 2, return : 1.000
# Episode : 5, length : 2, return : 1.000
# Episode : 6, length : 1, return : -1.000
# Episode : 7, length : 1, return : -1.000
# Episode : 8, length : 3, return : 0.000
# Episode : 9, length : 1, return : -1.000
# Episode : 10, length : 2, return : 1.000
# Episode : 11, length : 1, return : -1.000
# Episode : 12, length : 1, return : -1.000
# Episode : 13, length : 2, return : -1.000
# Episode : 14, length : 1, return : -1.000
# Episode : 15, length : 2, return : -1.000
# Episode : 16, length : 2, return : 1.000
# Episode : 17, length : 2, return : 1.000
# Episode : 18, length : 1, return : -1.000
# Episode : 19, length : 1, return : -1.000
# Episode : 20, length : 1, return : -1.000
# Episode : 21, length : 1, return : -1.000
# Episode : 22, length : 1, return : -1.000
# Episode : 23, length : 2, return : -1.000
# Episode : 24, length : 1, return : 1.000
# Episode : 25, length : 1, return : 1.000
# Episode : 26, length : 2, return : -1.000
# Episode : 27, length : 1, return : -1.000
# Episode : 28, length : 1, return : 1.000
# Episode : 29, length : 1, return : -1.000
# Episode : 30, length : 2, return : -1.000
# Episode : 31, length : 1, return : -1.000
# Episode : 32, length : 1, return : 1.000
# Episode : 33, length : 1, return : -1.000
# Episode : 34, length : 2, return : -1.000
# Episode : 35, length : 2, return : 1.000
# Episode : 36, length : 2, return : -1.000
# Episode : 37, length : 1, return : -1.000
# Episode : 38, length : 1, return : -1.000
# Episode : 39, length : 2, return : 0.000
# Episode : 40, length : 1, return : -1.000
# Episode : 41, length : 1, return : 1.000
# Episode : 42, length : 2, return : 0.000
# Episode : 43, length : 2, return : 1.000
# Episode : 44, length : 2, return : 1.000
# Episode : 45, length : 2, return : 0.000
# Episode : 46, length : 1, return : -1.000
# Episode : 47, length : 2, return : -1.000
# Episode : 48, length : 2, return : 0.000
# Episode : 49, length : 2, return : -1.000
# Episode : 50, length : 1, return : -1.000
# Episode : 51, length : 2, return : 1.000
# Episode : 52, length : 1, return : 0.000
# Episode : 53, length : 1, return : -1.000
# Episode : 54, length : 1, return : -1.000
# Episode : 55, length : 2, return : -1.000
# Episode : 56, length : 1, return : -1.000
# Episode : 57, length : 2, return : -1.000
# Episode : 58, length : 1, return : -1.000
# Episode : 59, length : 2, return : 0.000
# Episode : 60, length : 1, return : -1.000
# Episode : 61, length : 2, return : 1.000
# Episode : 62, length : 1, return : -1.000
# Episode : 63, length : 1, return : -1.000
# Episode : 64, length : 4, return : 0.000
# Episode : 65, length : 1, return : 1.000
# Episode : 66, length : 1, return : 1.000
# Episode : 67, length : 1, return : -1.000
# Episode : 68, length : 2, return : -1.000
# Episode : 69, length : 3, return : -1.000
# Episode : 70, length : 2, return : -1.000
# Episode : 71, length : 1, return : 1.000
# Episode : 72, length : 2, return : -1.000
# Episode : 73, length : 2, return : -1.000
# Episode : 74, length : 3, return : -1.000
# Episode : 75, length : 1, return : 1.000
# Episode : 76, length : 1, return : 1.000
# Episode : 77, length : 1, return : -1.000
# Episode : 78, length : 1, return : 1.000
# Episode : 79, length : 1, return : -1.000
# Episode : 80, length : 1, return : -1.000
# Episode : 81, length : 1, return : 0.000
# Episode : 82, length : 2, return : 1.000
# Episode : 83, length : 1, return : -1.000
# Episode : 84, length : 1, return : 1.000
# Episode : 85, length : 2, return : -1.000
# Episode : 86, length : 1, return : -1.000
# Episode : 87, length : 1, return : -1.000
# Episode : 88, length : 2, return : 1.000
# Episode : 89, length : 2, return : -1.000
# Episode : 90, length : 2, return : -1.000
# Episode : 91, length : 1, return : -1.000
# Episode : 92, length : 1, return : -1.000
# Episode : 93, length : 1, return : 1.000
# Episode : 94, length : 1, return : 1.000
# Episode : 95, length : 1, return : -1.000
# Episode : 96, length : 2, return : 1.000
# Episode : 97, length : 1, return : -1.000
# Episode : 98, length : 2, return : -1.000
# Episode : 99, length : 2, return : 1.000
# Episode : 100, length : 1, return : -1.000
# Episode : 101, length : 1, return : 1.000
# Episode : 102, length : 1, return : -1.000
# Episode : 103, length : 2, return : -1.000
# Episode : 104, length : 1, return : -1.000
# Episode : 105, length : 1, return : 1.000
# Episode : 106, length : 1, return : 1.000
# Episode : 107, length : 2, return : -1.000
# Episode : 108, length : 1, return : -1.000
# Episode : 109, length : 1, return : -1.000
# Episode : 110, length : 2, return : -1.000
# Episode : 111, length : 1, return : 1.000
# Episode : 112, length : 2, return : -1.000
# Episode : 113, length : 3, return : -1.000
# Episode : 114, length : 1, return : 1.000
# Episode : 115, length : 1, return : 1.000
# Episode : 116, length : 2, return : -1.000
# Episode : 117, length : 2, return : 1.000
# Episode : 118, length : 1, return : -1.000
# Episode : 119, length : 4, return : 1.000
# Episode : 120, length : 1, return : 1.000
# Episode : 121, length : 2, return : 1.000
# Episode : 122, length : 1, return : 1.000
# Episode : 123, length : 1, return : -1.000
# Episode : 124, length : 1, return : 0.000
# Episode : 125, length : 1, return : -1.000
# Episode : 126, length : 2, return : -1.000
# Episode : 127, length : 4, return : -1.000
# Episode : 128, length : 1, return : -1.000
# Episode : 129, length : 2, return : -1.000
# Episode : 130, length : 1, return : -1.000
# Episode : 131, length : 1, return : -1.000
# Episode : 132, length : 2, return : 1.000
# Episode : 133, length : 1, return : -1.000
# Episode : 134, length : 2, return : 0.000
# Episode : 135, length : 1, return : -1.000
# Episode : 136, length : 2, return : -1.000
# Episode : 137, length : 2, return : -1.000
# Episode : 138, length : 1, return : 1.000
# Episode : 139, length : 1, return : 1.000
# Episode : 140, length : 1, return : -1.000
# Episode : 141, length : 1, return : 1.000
# Episode : 142, length : 2, return : 1.000
# Episode : 143, length : 1, return : 1.000
# Episode : 144, length : 3, return : -1.000
# Episode : 145, length : 1, return : -1.000
# Episode : 146, length : 1, return : 1.000
# Episode : 147, length : 2, return : -1.000
# Episode : 148, length : 1, return : 1.000
# Episode : 149, length : 1, return : 1.000
# Episode : 150, length : 3, return : 1.000
# Episode : 151, length : 1, return : -1.000
# Episode : 152, length : 1, return : 1.000
# Episode : 153, length : 2, return : 1.000
# Episode : 154, length : 1, return : 1.000
# Episode : 155, length : 1, return : 1.000
# Episode : 156, length : 2, return : -1.000
# Episode : 157, length : 2, return : 1.000
# Episode : 158, length : 2, return : -1.000
# Episode : 159, length : 1, return : 1.000
# Episode : 160, length : 1, return : 0.000
# Episode : 161, length : 1, return : -1.000
# Episode : 162, length : 4, return : 0.000
# Episode : 163, length : 1, return : 1.000
# Episode : 164, length : 1, return : -1.000
# Episode : 165, length : 2, return : 1.000
# Episode : 166, length : 2, return : 1.000
# Episode : 167, length : 1, return : -1.000
# Episode : 168, length : 2, return : -1.000
# Episode : 169, length : 2, return : -1.000
# Episode : 170, length : 1, return : -1.000
# Episode : 171, length : 1, return : 1.000
# Episode : 172, length : 1, return : -1.000
# Episode : 173, length : 2, return : 0.000
# Episode : 174, length : 1, return : 1.000
# Episode : 175, length : 2, return : -1.000
# Episode : 176, length : 1, return : -1.000
# Episode : 177, length : 1, return : 1.000
# Episode : 178, length : 1, return : 1.000
# Episode : 179, length : 1, return : -1.000
# Episode : 180, length : 1, return : -1.000
# Episode : 181, length : 2, return : 0.000
# Episode : 182, length : 1, return : -1.000
# Episode : 183, length : 1, return : 1.000
# Episode : 184, length : 2, return : 1.000
# Episode : 185, length : 1, return : -1.000
# Episode : 186, length : 1, return : -1.000
# Episode : 187, length : 1, return : 1.000
# Episode : 188, length : 1, return : 1.000
# Episode : 189, length : 2, return : 1.000
# Episode : 190, length : 1, return : 1.000
# Episode : 191, length : 3, return : 1.000
# Episode : 192, length : 2, return : -1.000
# Episode : 193, length : 1, return : 0.000
# Episode : 194, length : 2, return : 0.000
# Episode : 195, length : 1, return : -1.000
# Episode : 196, length : 1, return : -1.000
# Episode : 197, length : 1, return : 1.000
# Episode : 198, length : 2, return : -1.000
# Episode : 199, length : 1, return : 1.000
# Episode : 200, length : 1, return : -1.000
# Episode : 201, length : 4, return : -1.000
# Episode : 202, length : 1, return : -1.000
# Episode : 203, length : 1, return : -1.000
# Episode : 204, length : 2, return : -1.000
# Episode : 205, length : 2, return : 1.000
# Episode : 206, length : 2, return : -1.000
# Episode : 207, length : 1, return : -1.000
# Episode : 208, length : 3, return : 1.000
# Episode : 209, length : 1, return : 1.000
# Episode : 210, length : 1, return : 0.000
# Episode : 211, length : 1, return : 1.000
# Episode : 212, length : 1, return : 1.000
# Episode : 213, length : 1, return : 1.000
# Episode : 214, length : 2, return : 0.000
# Episode : 215, length : 2, return : -1.000
# Episode : 216, length : 1, return : 1.000
# Episode : 217, length : 1, return : -1.000
# Episode : 218, length : 1, return : 0.000
# Episode : 219, length : 1, return : 1.000
# Episode : 220, length : 2, return : 0.000
# Episode : 221, length : 1, return : -1.000
# Episode : 222, length : 2, return : 1.000
# Episode : 223, length : 2, return : -1.000
# Episode : 224, length : 4, return : 0.000
# Episode : 225, length : 1, return : -1.000
# Episode : 226, length : 2, return : -1.000
# Episode : 227, length : 2, return : 0.000
# Episode : 228, length : 1, return : 1.000
# Episode : 229, length : 1, return : 1.000
# Episode : 230, length : 1, return : -1.000
# Episode : 231, length : 1, return : 1.000
# Episode : 232, length : 2, return : 1.000
# Episode : 233, length : 1, return : 1.000
# Episode : 234, length : 1, return : 1.000
# Episode : 235, length : 2, return : -1.000
# Episode : 236, length : 1, return : -1.000
# Episode : 237, length : 2, return : -1.000
# Episode : 238, length : 2, return : -1.000
# Episode : 239, length : 1, return : 1.000
# Episode : 240, length : 3, return : 1.000
# Episode : 241, length : 1, return : 1.000
# Episode : 242, length : 1, return : 1.000
# Episode : 243, length : 1, return : -1.000
# Episode : 244, length : 1, return : -1.000
# Episode : 245, length : 1, return : 1.000
# Episode : 246, length : 2, return : 1.000
# Episode : 247, length : 2, return : -1.000
# Episode : 248, length : 2, return : -1.000
# Episode : 249, length : 1, return : -1.000
# Episode : 250, length : 1, return : 1.000
# Episode : 251, length : 1, return : 0.000
# Episode : 252, length : 3, return : -1.000
# Episode : 253, length : 2, return : 1.000
# Episode : 254, length : 1, return : -1.000
# Episode : 255, length : 1, return : -1.000
# Episode : 256, length : 2, return : -1.000
# Episode : 257, length : 2, return : 1.000
# Episode : 258, length : 1, return : -1.000
# Episode : 259, length : 1, return : 1.000
# Episode : 260, length : 1, return : -1.000
# Episode : 261, length : 1, return : -1.000
# Episode : 262, length : 1, return : 1.000
# Episode : 263, length : 2, return : -1.000
# Episode : 264, length : 2, return : 1.000
# Episode : 265, length : 1, return : -1.000
# Episode : 266, length : 1, return : -1.000
# Episode : 267, length : 1, return : -1.000
# Episode : 268, length : 1, return : -1.000
# Episode : 269, length : 1, return : -1.000
# Episode : 270, length : 1, return : -1.000
# Episode : 271, length : 1, return : 1.000
# Episode : 272, length : 1, return : 0.000
# Episode : 273, length : 1, return : -1.000
# Episode : 274, length : 1, return : 1.000
# Episode : 275, length : 1, return : 1.000
# Episode : 276, length : 1, return : -1.000
# Episode : 277, length : 1, return : -1.000
# Episode : 278, length : 1, return : -1.000
# Episode : 279, length : 1, return : -1.000
# Episode : 280, length : 1, return : -1.000
# Episode : 281, length : 1, return : -1.000
# Episode : 282, length : 1, return : 1.000
# Episode : 283, length : 1, return : 1.000
# Episode : 284, length : 1, return : -1.000
# Episode : 285, length : 1, return : 1.000
# Episode : 286, length : 2, return : 1.000
# Episode : 287, length : 1, return : 1.000
# Episode : 288, length : 2, return : 1.000
# Episode : 289, length : 1, return : -1.000
# Episode : 290, length : 1, return : 1.000
# Episode : 291, length : 1, return : -1.000
# Episode : 292, length : 2, return : 1.000
# Episode : 293, length : 5, return : -1.000
# Episode : 294, length : 1, return : -1.000
# Episode : 295, length : 2, return : -1.000
# Episode : 296, length : 1, return : -1.000
# Episode : 297, length : 1, return : -1.000
# Episode : 298, length : 2, return : -1.000
# Episode : 299, length : 1, return : 0.000
# Episode : 300, length : 1, return : 0.000
# Episode : 301, length : 2, return : -1.000
# Episode : 302, length : 1, return : -1.000
# Episode : 303, length : 2, return : 1.000
# Episode : 304, length : 2, return : 1.000
# Episode : 305, length : 2, return : -1.000
# Episode : 306, length : 1, return : 1.000
# Episode : 307, length : 2, return : -1.000
# Episode : 308, length : 2, return : -1.000
# Episode : 309, length : 1, return : -1.000
# Episode : 310, length : 1, return : 1.000
# Episode : 311, length : 2, return : 1.000
# Episode : 312, length : 1, return : -1.000
# Episode : 313, length : 2, return : -1.000
# Episode : 314, length : 1, return : 1.000
# Episode : 315, length : 2, return : 1.000
# Episode : 316, length : 1, return : -1.000
# Episode : 317, length : 1, return : -1.000
# Episode : 318, length : 1, return : 1.000
# Episode : 319, length : 2, return : 1.000
# Episode : 320, length : 1, return : 1.000
# Episode : 321, length : 2, return : -1.000
# Episode : 322, length : 1, return : -1.000
# Episode : 323, length : 2, return : -1.000
# Episode : 324, length : 1, return : -1.000
# Episode : 325, length : 2, return : -1.000
# Episode : 326, length : 2, return : -1.000
# Episode : 327, length : 1, return : -1.000
# Episode : 328, length : 1, return : -1.000
# Episode : 329, length : 1, return : 0.000
# Episode : 330, length : 1, return : -1.000
# Episode : 331, length : 1, return : 1.000
# Episode : 332, length : 1, return : 1.000
# Episode : 333, length : 1, return : -1.000
# Episode : 334, length : 1, return : -1.000
# Episode : 335, length : 1, return : -1.000
# Episode : 336, length : 1, return : 1.000
# Episode : 337, length : 1, return : 1.000
# Episode : 338, length : 1, return : -1.000
# Episode : 339, length : 3, return : 1.000
# Episode : 340, length : 2, return : -1.000
# Episode : 341, length : 1, return : 1.000
# Episode : 342, length : 1, return : -1.000
# Episode : 343, length : 1, return : 1.000
# Episode : 344, length : 2, return : 1.000
# Episode : 345, length : 1, return : 1.000
# Episode : 346, length : 3, return : 0.000
# Episode : 347, length : 2, return : 1.000
# Episode : 348, length : 1, return : 1.000
# Episode : 349, length : 1, return : -1.000
# Episode : 350, length : 2, return : -1.000
# Episode : 351, length : 2, return : -1.000
# Episode : 352, length : 1, return : -1.000
# Episode : 353, length : 2, return : -1.000
# Episode : 354, length : 1, return : 1.000
# Episode : 355, length : 1, return : 1.000
# Episode : 356, length : 2, return : -1.000
# Episode : 357, length : 1, return : -1.000
# Episode : 358, length : 1, return : -1.000
# Episode : 359, length : 1, return : 1.000
# Episode : 360, length : 1, return : 1.000
# Episode : 361, length : 1, return : 1.000
# Episode : 362, length : 2, return : 1.000
# Episode : 363, length : 1, return : -1.000
# Episode : 364, length : 1, return : 1.000
# Episode : 365, length : 2, return : 1.000
# Episode : 366, length : 1, return : -1.000
# Episode : 367, length : 1, return : -1.000
# Episode : 368, length : 1, return : -1.000
# Episode : 369, length : 1, return : -1.000
# Episode : 370, length : 2, return : 1.000
# Episode : 371, length : 2, return : -1.000
# Episode : 372, length : 2, return : -1.000
# Episode : 373, length : 1, return : 1.000
# Episode : 374, length : 3, return : 1.000
# Episode : 375, length : 2, return : -1.000
# Episode : 376, length : 1, return : -1.000
# Episode : 377, length : 1, return : -1.000
# Episode : 378, length : 1, return : 1.000
# Episode : 379, length : 3, return : -1.000
# Episode : 380, length : 1, return : 1.000
# Episode : 381, length : 1, return : 0.000
# Episode : 382, length : 1, return : -1.000
# Episode : 383, length : 1, return : -1.000
# Episode : 384, length : 2, return : 0.000
# Episode : 385, length : 1, return : -1.000
# Episode : 386, length : 3, return : -1.000
# Episode : 387, length : 1, return : 1.000
# Episode : 388, length : 1, return : 1.000
# Episode : 389, length : 1, return : 1.000
# Episode : 390, length : 2, return : -1.000
# Episode : 391, length : 1, return : 1.000
# Episode : 392, length : 1, return : 1.000
# Episode : 393, length : 1, return : -1.000
# Episode : 394, length : 2, return : 1.000
# Episode : 395, length : 1, return : 1.000
# Episode : 396, length : 2, return : 1.000
# Episode : 397, length : 1, return : 1.000
# Episode : 398, length : 1, return : -1.000
# Episode : 399, length : 1, return : 1.000
# Episode : 400, length : 1, return : -1.000
# Episode : 401, length : 1, return : -1.000
# Episode : 402, length : 2, return : 1.000
# Episode : 403, length : 1, return : 1.000
# Episode : 404, length : 1, return : 1.000
# Episode : 405, length : 1, return : -1.000
# Episode : 406, length : 2, return : 1.000
# Episode : 407, length : 1, return : -1.000
# Episode : 408, length : 1, return : -1.000
# Episode : 409, length : 1, return : 1.000
# Episode : 410, length : 1, return : 1.000
# Episode : 411, length : 1, return : -1.000
# Episode : 412, length : 2, return : -1.000
# Episode : 413, length : 2, return : -1.000
# Episode : 414, length : 1, return : -1.000
# Episode : 415, length : 1, return : 1.000
# Episode : 416, length : 1, return : -1.000
# Episode : 417, length : 1, return : 1.000
# Episode : 418, length : 1, return : 0.000
# Episode : 419, length : 1, return : -1.000
# Episode : 420, length : 1, return : 1.000
# Episode : 421, length : 3, return : 1.000
# Episode : 422, length : 1, return : -1.000
# Episode : 423, length : 3, return : -1.000
# Episode : 424, length : 1, return : 1.000
# Episode : 425, length : 3, return : 1.000
# Episode : 426, length : 1, return : 1.000
# Episode : 427, length : 1, return : -1.000
# Episode : 428, length : 1, return : -1.000
# Episode : 429, length : 2, return : -1.000
# Episode : 430, length : 1, return : -1.000
# Episode : 431, length : 2, return : -1.000
# Episode : 432, length : 1, return : -1.000
# Episode : 433, length : 1, return : -1.000
# Episode : 434, length : 2, return : 1.000
# Episode : 435, length : 2, return : -1.000
# Episode : 436, length : 2, return : -1.000
# Episode : 437, length : 1, return : -1.000
# Episode : 438, length : 4, return : 1.000
# Episode : 439, length : 1, return : 1.000
# Episode : 440, length : 1, return : -1.000
# Episode : 441, length : 3, return : 1.000
# Episode : 442, length : 2, return : -1.000
# Episode : 443, length : 1, return : 1.000
# Episode : 444, length : 2, return : 1.000
# Episode : 445, length : 2, return : 1.000
# Episode : 446, length : 1, return : 1.000
# Episode : 447, length : 2, return : 1.000
# Episode : 448, length : 2, return : 0.000
# Episode : 449, length : 1, return : -1.000
# Episode : 450, length : 1, return : -1.000
# Episode : 451, length : 1, return : -1.000
# Episode : 452, length : 2, return : 1.000
# Episode : 453, length : 1, return : -1.000
# Episode : 454, length : 2, return : -1.000
# Episode : 455, length : 1, return : -1.000
# Episode : 456, length : 1, return : 1.000
# Episode : 457, length : 1, return : -1.000
# Episode : 458, length : 1, return : 1.000
# Episode : 459, length : 3, return : 1.000
# Episode : 460, length : 4, return : 1.000
# Episode : 461, length : 1, return : -1.000
# Episode : 462, length : 2, return : 1.000
# Episode : 463, length : 2, return : -1.000
# Episode : 464, length : 1, return : 1.000
# Episode : 465, length : 1, return : 1.000
# Episode : 466, length : 1, return : 0.000
# Episode : 467, length : 1, return : -1.000
# Episode : 468, length : 1, return : 1.000
# Episode : 469, length : 3, return : -1.000
# Episode : 470, length : 1, return : -1.000
# Episode : 471, length : 1, return : 1.000
# Episode : 472, length : 1, return : -1.000
# Episode : 473, length : 1, return : -1.000
# Episode : 474, length : 1, return : -1.000
# Episode : 475, length : 1, return : -1.000
# Episode : 476, length : 1, return : 1.000
# Episode : 477, length : 1, return : -1.000
# Episode : 478, length : 1, return : 1.000
# Episode : 479, length : 1, return : -1.000
# Episode : 480, length : 1, return : -1.000
# Episode : 481, length : 1, return : 0.000
# Episode : 482, length : 2, return : 1.000
# Episode : 483, length : 1, return : -1.000
# Episode : 484, length : 1, return : 1.000
# Episode : 485, length : 1, return : -1.000
# Episode : 486, length : 1, return : 1.000
# Episode : 487, length : 1, return : -1.000
# Episode : 488, length : 1, return : 1.000
# Episode : 489, length : 2, return : 1.000
# Episode : 490, length : 2, return : -1.000
# Episode : 491, length : 1, return : 1.000
# Episode : 492, length : 1, return : -1.000
# Episode : 493, length : 2, return : 1.000
# Episode : 494, length : 1, return : -1.000
# Episode : 495, length : 3, return : 1.000
# Episode : 496, length : 2, return : -1.000
# Episode : 497, length : 1, return : -1.000
# Episode : 498, length : 3, return : 1.000
# Episode : 499, length : 1, return : 1.000
# Episode : 500, length : 1, return : -1.000
# Episode : 501, length : 1, return : 1.000
# Episode : 502, length : 2, return : 1.000
# Episode : 503, length : 2, return : -1.000
# Episode : 504, length : 2, return : 0.000
# Episode : 505, length : 1, return : -1.000
# Episode : 506, length : 1, return : 1.000
# Episode : 507, length : 1, return : 1.000
# Episode : 508, length : 1, return : -1.000
# Episode : 509, length : 1, return : 1.000
# Episode : 510, length : 1, return : 1.000
# Episode : 511, length : 1, return : 1.000
# Episode : 512, length : 1, return : 1.000
# Episode : 513, length : 1, return : 0.000
# Episode : 514, length : 1, return : -1.000
# Episode : 515, length : 2, return : -1.000
# Episode : 516, length : 2, return : 1.000
# Episode : 517, length : 1, return : -1.000
# Episode : 518, length : 1, return : 1.000
# Episode : 519, length : 2, return : 1.000
# Episode : 520, length : 2, return : -1.000
# Episode : 521, length : 1, return : 0.000
# Episode : 522, length : 1, return : -1.000
# Episode : 523, length : 1, return : -1.000
# Episode : 524, length : 1, return : 1.000
# Episode : 525, length : 1, return : -1.000
# Episode : 526, length : 1, return : -1.000
# Episode : 527, length : 1, return : 1.000
# Episode : 528, length : 1, return : 1.000
# Episode : 529, length : 2, return : 1.000
# Episode : 530, length : 1, return : -1.000
# Episode : 531, length : 2, return : 1.000
# Episode : 532, length : 1, return : -1.000
# Episode : 533, length : 2, return : -1.000
# Episode : 534, length : 1, return : 1.000
# Episode : 535, length : 2, return : 0.000
# Episode : 536, length : 1, return : 1.000
# Episode : 537, length : 2, return : 1.000
# Episode : 538, length : 1, return : -1.000
# Episode : 539, length : 3, return : 1.000
# Episode : 540, length : 1, return : -1.000
# Episode : 541, length : 2, return : -1.000
# Episode : 542, length : 2, return : -1.000
# Episode : 543, length : 3, return : -1.000
# Episode : 544, length : 2, return : -1.000
# Episode : 545, length : 3, return : 1.000
# Episode : 546, length : 1, return : 1.000
# Episode : 547, length : 2, return : -1.000
# Episode : 548, length : 1, return : -1.000
# Episode : 549, length : 2, return : -1.000
# Episode : 550, length : 1, return : -1.000
# Episode : 551, length : 1, return : -1.000
# Episode : 552, length : 3, return : 1.000
# Episode : 553, length : 1, return : 1.000
# Episode : 554, length : 1, return : 1.000
# Episode : 555, length : 1, return : 1.000
# Episode : 556, length : 1, return : 1.000
# Episode : 557, length : 1, return : 1.000
# Episode : 558, length : 1, return : 1.000
# Episode : 559, length : 2, return : 1.000
# Episode : 560, length : 1, return : -1.000
# Episode : 561, length : 2, return : -1.000
# Episode : 562, length : 3, return : -1.000
# Episode : 563, length : 2, return : -1.000
# Episode : 564, length : 1, return : -1.000
# Episode : 565, length : 2, return : -1.000
# Episode : 566, length : 1, return : -1.000
# Episode : 567, length : 1, return : 1.000
# Episode : 568, length : 1, return : -1.000
# Episode : 569, length : 2, return : -1.000
# Episode : 570, length : 1, return : 0.000
# Episode : 571, length : 1, return : 1.000
# Episode : 572, length : 1, return : -1.000
# Episode : 573, length : 1, return : -1.000
# Episode : 574, length : 1, return : -1.000
# Episode : 575, length : 2, return : 1.000
# Episode : 576, length : 1, return : -1.000
# Episode : 577, length : 3, return : 0.000
# Episode : 578, length : 2, return : 0.000
# Episode : 579, length : 1, return : 1.000
# Episode : 580, length : 1, return : -1.000
# Episode : 581, length : 1, return : 1.000
# Episode : 582, length : 1, return : -1.000
# Episode : 583, length : 2, return : -1.000
# Episode : 584, length : 2, return : -1.000
# Episode : 585, length : 1, return : 1.000
# Episode : 586, length : 1, return : -1.000
# Episode : 587, length : 1, return : -1.000
# Episode : 588, length : 1, return : -1.000
# Episode : 589, length : 1, return : -1.000
# Episode : 590, length : 2, return : -1.000
# Episode : 591, length : 1, return : 1.000
# Episode : 592, length : 1, return : -1.000
# Episode : 593, length : 1, return : 1.000
# Episode : 594, length : 1, return : 1.000
# Episode : 595, length : 1, return : 0.000
# Episode : 596, length : 1, return : 1.000
# Episode : 597, length : 2, return : -1.000
# Episode : 598, length : 1, return : 1.000
# Episode : 599, length : 2, return : 1.000
# Episode : 600, length : 1, return : -1.000
# Episode : 601, length : 1, return : 1.000
# Episode : 602, length : 1, return : 1.000
# Episode : 603, length : 1, return : -1.000
# Episode : 604, length : 1, return : 1.000
# Episode : 605, length : 1, return : -1.000
# Episode : 606, length : 1, return : 1.000
# Episode : 607, length : 2, return : 0.000
# Episode : 608, length : 2, return : -1.000
# Episode : 609, length : 1, return : -1.000
# Episode : 610, length : 2, return : -1.000
# Episode : 611, length : 2, return : 1.000
# Episode : 612, length : 1, return : -1.000
# Episode : 613, length : 2, return : 0.000
# Episode : 614, length : 1, return : -1.000
# Episode : 615, length : 1, return : 1.000
# Episode : 616, length : 1, return : 1.000
# Episode : 617, length : 3, return : -1.000
# Episode : 618, length : 3, return : 1.000
# Episode : 619, length : 2, return : 1.000
# Episode : 620, length : 1, return : 1.000
# Episode : 621, length : 1, return : -1.000
# Episode : 622, length : 2, return : -1.000
# Episode : 623, length : 1, return : -1.000
# Episode : 624, length : 1, return : 1.000
# Episode : 625, length : 3, return : -1.000
# Episode : 626, length : 1, return : 1.000
# Episode : 627, length : 1, return : -1.000
# Episode : 628, length : 2, return : 1.000
# Episode : 629, length : 2, return : -1.000
# Episode : 630, length : 1, return : 1.000
# Episode : 631, length : 2, return : 0.000
# Episode : 632, length : 1, return : -1.000
# Episode : 633, length : 1, return : -1.000
# Episode : 634, length : 2, return : 1.000
# Episode : 635, length : 1, return : 1.000
# Episode : 636, length : 1, return : -1.000
# Episode : 637, length : 1, return : -1.000
# Episode : 638, length : 1, return : -1.000
# Episode : 639, length : 4, return : -1.000
# Episode : 640, length : 2, return : -1.000
# Episode : 641, length : 2, return : -1.000
# Episode : 642, length : 1, return : -1.000
# Episode : 643, length : 1, return : -1.000
# Episode : 644, length : 2, return : -1.000
# Episode : 645, length : 1, return : -1.000
# Episode : 646, length : 1, return : -1.000
# Episode : 647, length : 1, return : 1.000
# Episode : 648, length : 2, return : -1.000
# Episode : 649, length : 2, return : -1.000
# Episode : 650, length : 1, return : 1.000
# Episode : 651, length : 1, return : -1.000
# Episode : 652, length : 1, return : -1.000
# Episode : 653, length : 1, return : -1.000
# Episode : 654, length : 1, return : -1.000
# Episode : 655, length : 1, return : -1.000
# Episode : 656, length : 3, return : 0.000
# Episode : 657, length : 1, return : -1.000
# Episode : 658, length : 1, return : -1.000
# Episode : 659, length : 1, return : -1.000
# Episode : 660, length : 1, return : 1.000
# Episode : 661, length : 1, return : -1.000
# Episode : 662, length : 1, return : -1.000
# Episode : 663, length : 1, return : -1.000
# Episode : 664, length : 2, return : 1.000
# Episode : 665, length : 1, return : -1.000
# Episode : 666, length : 1, return : -1.000
# Episode : 667, length : 2, return : -1.000
# Episode : 668, length : 1, return : 1.000
# Episode : 669, length : 2, return : -1.000
# Episode : 670, length : 2, return : 1.000
# Episode : 671, length : 1, return : 0.000
# Episode : 672, length : 1, return : 1.000
# Episode : 673, length : 1, return : -1.000
# Episode : 674, length : 1, return : -1.000
# Episode : 675, length : 2, return : -1.000
# Episode : 676, length : 1, return : 0.000
# Episode : 677, length : 1, return : 1.000
# Episode : 678, length : 1, return : 1.000
# Episode : 679, length : 2, return : 1.000
# Episode : 680, length : 2, return : 1.000
# Episode : 681, length : 1, return : 1.000
# Episode : 682, length : 1, return : 1.000
# Episode : 683, length : 2, return : -1.000
# Episode : 684, length : 1, return : 1.000
# Episode : 685, length : 1, return : 1.000
# Episode : 686, length : 2, return : 1.000
# Episode : 687, length : 2, return : 1.000
# Episode : 688, length : 1, return : -1.000
# Episode : 689, length : 1, return : 1.000
# Episode : 690, length : 2, return : 1.000
# Episode : 691, length : 1, return : -1.000
# Episode : 692, length : 1, return : -1.000
# Episode : 693, length : 2, return : 0.000
# Episode : 694, length : 1, return : -1.000
# Episode : 695, length : 1, return : 1.000
# Episode : 696, length : 1, return : -1.000
# Episode : 697, length : 1, return : -1.000
# Episode : 698, length : 1, return : -1.000
# Episode : 699, length : 1, return : 1.000
# Episode : 700, length : 1, return : -1.000
# Episode : 701, length : 2, return : -1.000
# Episode : 702, length : 1, return : 1.000
# Episode : 703, length : 1, return : 1.000
# Episode : 704, length : 2, return : -1.000
# Episode : 705, length : 2, return : 1.000
# Episode : 706, length : 3, return : 1.000
# Episode : 707, length : 1, return : -1.000
# Episode : 708, length : 2, return : -1.000
# Episode : 709, length : 1, return : 1.000
# Episode : 710, length : 2, return : -1.000
# Episode : 711, length : 2, return : 1.000
# Episode : 712, length : 1, return : 1.000
# Episode : 713, length : 1, return : 1.000
# Episode : 714, length : 2, return : -1.000
# Episode : 715, length : 1, return : 1.000
# Episode : 716, length : 1, return : 1.000
# Episode : 717, length : 1, return : 1.000
# Episode : 718, length : 1, return : 1.000
# Episode : 719, length : 1, return : -1.000
# Episode : 720, length : 1, return : 1.000
# Episode : 721, length : 2, return : 1.000
# Episode : 722, length : 1, return : -1.000
# Episode : 723, length : 1, return : 1.000
# Episode : 724, length : 1, return : 1.000
# Episode : 725, length : 1, return : -1.000
# Episode : 726, length : 2, return : -1.000
# Episode : 727, length : 2, return : 1.000
# Episode : 728, length : 1, return : -1.000
# Episode : 729, length : 1, return : -1.000
# Episode : 730, length : 1, return : 1.000
# Episode : 731, length : 1, return : 1.000
# Episode : 732, length : 1, return : -1.000
# Episode : 733, length : 1, return : -1.000
# Episode : 734, length : 1, return : 0.000
# Episode : 735, length : 1, return : -1.000
# Episode : 736, length : 1, return : 1.000
# Episode : 737, length : 2, return : -1.000
# Episode : 738, length : 2, return : 1.000
# Episode : 739, length : 2, return : 1.000
# Episode : 740, length : 2, return : 1.000
# Episode : 741, length : 1, return : 1.000
# Episode : 742, length : 1, return : -1.000
# Episode : 743, length : 1, return : 1.000
# Episode : 744, length : 1, return : -1.000
# Episode : 745, length : 2, return : -1.000
# Episode : 746, length : 1, return : -1.000
# Episode : 747, length : 1, return : 1.000
# Episode : 748, length : 1, return : -1.000
# Episode : 749, length : 1, return : 1.000
# Episode : 750, length : 1, return : -1.000
# Episode : 751, length : 1, return : 1.000
# Episode : 752, length : 1, return : 1.000
# Episode : 753, length : 1, return : 1.000
# Episode : 754, length : 1, return : -1.000
# Episode : 755, length : 1, return : -1.000
# Episode : 756, length : 3, return : 1.000
# Episode : 757, length : 2, return : 0.000
# Episode : 758, length : 2, return : -1.000
# Episode : 759, length : 3, return : 0.000
# Episode : 760, length : 2, return : 0.000
# Episode : 761, length : 1, return : 1.000
# Episode : 762, length : 1, return : -1.000
# Episode : 763, length : 1, return : -1.000
# Episode : 764, length : 1, return : -1.000
# Episode : 765, length : 1, return : -1.000
# Episode : 766, length : 2, return : -1.000
# Episode : 767, length : 2, return : 1.000
# Episode : 768, length : 2, return : -1.000
# Episode : 769, length : 2, return : -1.000
# Episode : 770, length : 1, return : 1.000
# Episode : 771, length : 2, return : -1.000
# Episode : 772, length : 1, return : -1.000
# Episode : 773, length : 4, return : -1.000
# Episode : 774, length : 2, return : -1.000
# Episode : 775, length : 4, return : 1.000
# Episode : 776, length : 1, return : -1.000
# Episode : 777, length : 1, return : 1.000
# Episode : 778, length : 2, return : 1.000
# Episode : 779, length : 1, return : 1.000
# Episode : 780, length : 1, return : -1.000
# Episode : 781, length : 1, return : -1.000
# Episode : 782, length : 1, return : 1.000
# Episode : 783, length : 1, return : -1.000
# Episode : 784, length : 1, return : 1.000
# Episode : 785, length : 1, return : 1.000
# Episode : 786, length : 2, return : 1.000
# Episode : 787, length : 1, return : -1.000
# Episode : 788, length : 1, return : -1.000
# Episode : 789, length : 2, return : 1.000
# Episode : 790, length : 2, return : 0.000
# Episode : 791, length : 2, return : 1.000
# Episode : 792, length : 1, return : -1.000
# Episode : 793, length : 1, return : 1.000
# Episode : 794, length : 2, return : 1.000
# Episode : 795, length : 1, return : -1.000
# Episode : 796, length : 4, return : -1.000
# Episode : 797, length : 2, return : 1.000
# Episode : 798, length : 1, return : -1.000
# Episode : 799, length : 1, return : 1.000
# Episode : 800, length : 2, return : 1.000
# Episode : 801, length : 1, return : 1.000
# Episode : 802, length : 2, return : 1.000
# Episode : 803, length : 2, return : -1.000
# Episode : 804, length : 3, return : 1.000
# Episode : 805, length : 1, return : 1.000
# Episode : 806, length : 1, return : -1.000
# Episode : 807, length : 1, return : -1.000
# Episode : 808, length : 1, return : -1.000
# Episode : 809, length : 2, return : -1.000
# Episode : 810, length : 1, return : 1.000
# Episode : 811, length : 2, return : -1.000
# Episode : 812, length : 1, return : -1.000
# Episode : 813, length : 1, return : -1.000
# Episode : 814, length : 4, return : 1.000
# Episode : 815, length : 1, return : -1.000
# Episode : 816, length : 1, return : 1.000
# Episode : 817, length : 2, return : 1.000
# Episode : 818, length : 1, return : -1.000
# Episode : 819, length : 1, return : -1.000
# Episode : 820, length : 2, return : 0.000
# Episode : 821, length : 3, return : 1.000
# Episode : 822, length : 1, return : 0.000
# Episode : 823, length : 1, return : -1.000
# Episode : 824, length : 1, return : -1.000
# Episode : 825, length : 1, return : 0.000
# Episode : 826, length : 1, return : -1.000
# Episode : 827, length : 1, return : 0.000
# Episode : 828, length : 1, return : -1.000
# Episode : 829, length : 2, return : -1.000
# Episode : 830, length : 1, return : -1.000
# Episode : 831, length : 1, return : -1.000
# Episode : 832, length : 2, return : -1.000
# Episode : 833, length : 1, return : -1.000
# Episode : 834, length : 2, return : 1.000
# Episode : 835, length : 2, return : 1.000
# Episode : 836, length : 1, return : 1.000
# Episode : 837, length : 1, return : -1.000
# Episode : 838, length : 1, return : -1.000
# Episode : 839, length : 2, return : 1.000
# Episode : 840, length : 1, return : -1.000
# Episode : 841, length : 2, return : 0.000
# Episode : 842, length : 2, return : -1.000
# Episode : 843, length : 1, return : 1.000
# Episode : 844, length : 2, return : -1.000
# Episode : 845, length : 2, return : -1.000
# Episode : 846, length : 1, return : 0.000
# Episode : 847, length : 2, return : 1.000
# Episode : 848, length : 1, return : -1.000
# Episode : 849, length : 1, return : -1.000
# Episode : 850, length : 1, return : -1.000
# Episode : 851, length : 1, return : 1.000
# Episode : 852, length : 1, return : 1.000
# Episode : 853, length : 1, return : -1.000
# Episode : 854, length : 2, return : 0.000
# Episode : 855, length : 1, return : 1.000
# Episode : 856, length : 1, return : 0.000
# Episode : 857, length : 1, return : 1.000
# Episode : 858, length : 2, return : -1.000
# Episode : 859, length : 1, return : -1.000
# Episode : 860, length : 3, return : 1.000
# Episode : 861, length : 1, return : -1.000
# Episode : 862, length : 2, return : -1.000
# Episode : 863, length : 1, return : -1.000
# Episode : 864, length : 1, return : 1.000
# Episode : 865, length : 3, return : -1.000
# Episode : 866, length : 1, return : -1.000
# Episode : 867, length : 1, return : 1.000
# Episode : 868, length : 1, return : 1.000
# Episode : 869, length : 2, return : -1.000
# Episode : 870, length : 1, return : 1.000
# Episode : 871, length : 1, return : 1.000
# Episode : 872, length : 1, return : -1.000
# Episode : 873, length : 1, return : 1.000
# Episode : 874, length : 2, return : 1.000
# Episode : 875, length : 1, return : -1.000
# Episode : 876, length : 1, return : -1.000
# Episode : 877, length : 1, return : -1.000
# Episode : 878, length : 2, return : 1.000
# Episode : 879, length : 2, return : 1.000
# Episode : 880, length : 1, return : -1.000
# Episode : 881, length : 2, return : 1.000
# Episode : 882, length : 3, return : 1.000
# Episode : 883, length : 1, return : -1.000
# Episode : 884, length : 2, return : -1.000
# Episode : 885, length : 1, return : -1.000
# Episode : 886, length : 3, return : 0.000
# Episode : 887, length : 1, return : 1.000
# Episode : 888, length : 3, return : 1.000
# Episode : 889, length : 1, return : -1.000
# Episode : 890, length : 1, return : -1.000
# Episode : 891, length : 1, return : -1.000
# Episode : 892, length : 1, return : -1.000
# Episode : 893, length : 1, return : -1.000
# Episode : 894, length : 1, return : -1.000
# Episode : 895, length : 1, return : 1.000
# Episode : 896, length : 1, return : 1.000
# Episode : 897, length : 1, return : -1.000
# Episode : 898, length : 1, return : -1.000
# Episode : 899, length : 2, return : -1.000
# Episode : 900, length : 1, return : -1.000
# Episode : 901, length : 4, return : -1.000
# Episode : 902, length : 2, return : 1.000
# Episode : 903, length : 1, return : -1.000
# Episode : 904, length : 1, return : 0.000
# Episode : 905, length : 2, return : 1.000
# Episode : 906, length : 1, return : -1.000
# Episode : 907, length : 1, return : 1.000
# Episode : 908, length : 1, return : -1.000
# Episode : 909, length : 1, return : -1.000
# Episode : 910, length : 1, return : -1.000
# Episode : 911, length : 1, return : -1.000
# Episode : 912, length : 1, return : 1.000
# Episode : 913, length : 2, return : -1.000
# Episode : 914, length : 1, return : 1.000
# Episode : 915, length : 1, return : 1.000
# Episode : 916, length : 3, return : 1.000
# Episode : 917, length : 1, return : 1.000
# Episode : 918, length : 1, return : -1.000
# Episode : 919, length : 2, return : -1.000
# Episode : 920, length : 1, return : 1.000
# Episode : 921, length : 1, return : 1.000
# Episode : 922, length : 1, return : 1.000
# Episode : 923, length : 1, return : -1.000
# Episode : 924, length : 1, return : -1.000
# Episode : 925, length : 1, return : -1.000
# Episode : 926, length : 1, return : 1.000
# Episode : 927, length : 2, return : -1.000
# Episode : 928, length : 1, return : 1.000
# Episode : 929, length : 1, return : -1.000
# Episode : 930, length : 1, return : -1.000
# Episode : 931, length : 3, return : -1.000
# Episode : 932, length : 2, return : -1.000
# Episode : 933, length : 1, return : 1.000
# Episode : 934, length : 1, return : -1.000
# Episode : 935, length : 1, return : 1.000
# Episode : 936, length : 1, return : 1.000
# Episode : 937, length : 3, return : 1.000
# Episode : 938, length : 1, return : 1.000
# Episode : 939, length : 1, return : 1.000
# Episode : 940, length : 1, return : -1.000
# Episode : 941, length : 1, return : -1.000
# Episode : 942, length : 1, return : -1.000
# Episode : 943, length : 1, return : 1.000
# Episode : 944, length : 2, return : -1.000
# Episode : 945, length : 1, return : 1.000
# Episode : 946, length : 1, return : -1.000
# Episode : 947, length : 3, return : 1.000
# Episode : 948, length : 3, return : 1.000
# Episode : 949, length : 1, return : -1.000
# Episode : 950, length : 3, return : 1.000
# Episode : 951, length : 1, return : 1.000
# Episode : 952, length : 1, return : 1.000
# Episode : 953, length : 1, return : 1.000
# Episode : 954, length : 1, return : 0.000
# Episode : 955, length : 1, return : 1.000
# Episode : 956, length : 1, return : 1.000
# Episode : 957, length : 2, return : -1.000
# Episode : 958, length : 3, return : 1.000
# Episode : 959, length : 2, return : 1.000
# Episode : 960, length : 1, return : -1.000
# Episode : 961, length : 1, return : -1.000
# Episode : 962, length : 4, return : -1.000
# Episode : 963, length : 1, return : -1.000
# Episode : 964, length : 2, return : -1.000
# Episode : 965, length : 2, return : 1.000
# Episode : 966, length : 1, return : 1.000
# Episode : 967, length : 1, return : 1.000
# Episode : 968, length : 1, return : -1.000
# Episode : 969, length : 1, return : -1.000
# Episode : 970, length : 1, return : -1.000
# Episode : 971, length : 1, return : -1.000
# Episode : 972, length : 1, return : -1.000
# Episode : 973, length : 3, return : -1.000
# Episode : 974, length : 2, return : -1.000
# Episode : 975, length : 1, return : -1.000
# Episode : 976, length : 2, return : 1.000
# Episode : 977, length : 1, return : 1.000
# Episode : 978, length : 1, return : -1.000
# Episode : 979, length : 3, return : 1.000
# Episode : 980, length : 1, return : -1.000
# Episode : 981, length : 2, return : -1.000
# Episode : 982, length : 1, return : 1.000
# Episode : 983, length : 2, return : -1.000
# Episode : 984, length : 1, return : -1.000
# Episode : 985, length : 1, return : 1.000
# Episode : 986, length : 1, return : -1.000
# Episode : 987, length : 2, return : -1.000
# Episode : 988, length : 1, return : -1.000
# Episode : 989, length : 2, return : 1.000
# Episode : 990, length : 2, return : 1.000
# Episode : 991, length : 1, return : 1.000
# Episode : 992, length : 2, return : -1.000
# Episode : 993, length : 1, return : -1.000
# Episode : 994, length : 1, return : -1.000
# Episode : 995, length : 1, return : -1.000
# Episode : 996, length : 4, return : 1.000
# Episode : 997, length : 1, return : 1.000
# Episode : 998, length : 1, return : -1.000
# Episode : 999, length : 2, return : -1.000
# Episode : 1000, length : 1, return : -1.000
# Episode : 1001, length : 1, return : 1.000
# Episode : 1002, length : 1, return : -1.000
# Episode : 1003, length : 1, return : 1.000
# Episode : 1004, length : 2, return : -1.000
# Episode : 1005, length : 1, return : 0.000
# Episode : 1006, length : 2, return : 1.000
# Episode : 1007, length : 1, return : -1.000
# Episode : 1008, length : 2, return : 0.000
# Episode : 1009, length : 1, return : 1.000
# Episode : 1010, length : 1, return : 1.000
# Episode : 1011, length : 1, return : 1.000
# Episode : 1012, length : 1, return : 1.000
# Episode : 1013, length : 1, return : 1.000
# Episode : 1014, length : 2, return : 1.000
# Episode : 1015, length : 1, return : -1.000
# Episode : 1016, length : 1, return : 1.000
# Episode : 1017, length : 1, return : -1.000
# Episode : 1018, length : 2, return : 0.000
# Episode : 1019, length : 1, return : 0.000
# Episode : 1020, length : 1, return : -1.000
# Episode : 1021, length : 1, return : -1.000
# Episode : 1022, length : 3, return : 1.000
# Episode : 1023, length : 1, return : 1.000
# Episode : 1024, length : 1, return : -1.000
# Episode : 1025, length : 2, return : -1.000
# Episode : 1026, length : 1, return : -1.000
# Episode : 1027, length : 1, return : 1.000
# Episode : 1028, length : 1, return : 1.000
# Episode : 1029, length : 2, return : 1.000
# Episode : 1030, length : 1, return : -1.000
# Episode : 1031, length : 1, return : 0.000
# Episode : 1032, length : 1, return : -1.000
# Episode : 1033, length : 1, return : -1.000
# Episode : 1034, length : 3, return : 0.000
# Episode : 1035, length : 2, return : -1.000
# Episode : 1036, length : 1, return : -1.000
# Episode : 1037, length : 1, return : -1.000
# Episode : 1038, length : 3, return : 0.000
# Episode : 1039, length : 1, return : 1.000
# Episode : 1040, length : 1, return : -1.000
# Episode : 1041, length : 2, return : 1.000
# Episode : 1042, length : 2, return : 1.000
# Episode : 1043, length : 1, return : -1.000
# Episode : 1044, length : 2, return : -1.000
# Episode : 1045, length : 1, return : -1.000
# Episode : 1046, length : 2, return : -1.000
# Episode : 1047, length : 2, return : 1.000
# Episode : 1048, length : 2, return : -1.000
# Episode : 1049, length : 1, return : -1.000
# Episode : 1050, length : 2, return : 0.000
# Episode : 1051, length : 2, return : -1.000
# Episode : 1052, length : 1, return : -1.000
# Episode : 1053, length : 2, return : 1.000
# Episode : 1054, length : 1, return : 1.000
# Episode : 1055, length : 1, return : -1.000
# Episode : 1056, length : 1, return : 1.000
# Episode : 1057, length : 2, return : 1.000
# Episode : 1058, length : 1, return : 1.000
# Episode : 1059, length : 1, return : 1.000
# Episode : 1060, length : 1, return : 1.000
# Episode : 1061, length : 1, return : -1.000
# Episode : 1062, length : 1, return : -1.000
# Episode : 1063, length : 2, return : 0.000
# Episode : 1064, length : 1, return : 1.000
# Episode : 1065, length : 1, return : -1.000
# Episode : 1066, length : 1, return : 1.000
# Episode : 1067, length : 2, return : -1.000
# Episode : 1068, length : 2, return : 1.000
# Episode : 1069, length : 3, return : 1.000
# Episode : 1070, length : 1, return : 1.000
# Episode : 1071, length : 1, return : -1.000
# Episode : 1072, length : 1, return : 1.000
# Episode : 1073, length : 1, return : 1.000
# Episode : 1074, length : 2, return : 1.000
# Episode : 1075, length : 3, return : 1.000
# Episode : 1076, length : 1, return : -1.000
# Episode : 1077, length : 1, return : -1.000
# Episode : 1078, length : 1, return : -1.000
# Episode : 1079, length : 1, return : -1.000
# Episode : 1080, length : 1, return : -1.000
# Episode : 1081, length : 1, return : 0.000
# Episode : 1082, length : 2, return : 1.000
# Episode : 1083, length : 1, return : 1.000
# Episode : 1084, length : 2, return : 1.000
# Episode : 1085, length : 1, return : -1.000
# Episode : 1086, length : 1, return : 1.000
# Episode : 1087, length : 1, return : -1.000
# Episode : 1088, length : 1, return : -1.000
# Episode : 1089, length : 1, return : -1.000
# Episode : 1090, length : 1, return : -1.000
# Episode : 1091, length : 1, return : 0.000
# Episode : 1092, length : 1, return : -1.000
# Episode : 1093, length : 2, return : -1.000
# Episode : 1094, length : 1, return : -1.000
# Episode : 1095, length : 2, return : -1.000
# Episode : 1096, length : 1, return : -1.000
# Episode : 1097, length : 1, return : -1.000
# Episode : 1098, length : 2, return : 1.000
# Episode : 1099, length : 1, return : -1.000
# Episode : 1100, length : 1, return : 1.000
# Episode : 1101, length : 2, return : -1.000
# Episode : 1102, length : 3, return : -1.000
# Episode : 1103, length : 1, return : -1.000
# Episode : 1104, length : 1, return : -1.000
# Episode : 1105, length : 1, return : -1.000
# Episode : 1106, length : 1, return : -1.000
# Episode : 1107, length : 2, return : -1.000
# Episode : 1108, length : 3, return : -1.000
# Episode : 1109, length : 2, return : -1.000
# Episode : 1110, length : 1, return : -1.000
# Episode : 1111, length : 1, return : -1.000
# Episode : 1112, length : 2, return : 0.000
# Episode : 1113, length : 1, return : -1.000
# Episode : 1114, length : 1, return : -1.000
# Episode : 1115, length : 2, return : -1.000
# Episode : 1116, length : 1, return : -1.000
# Episode : 1117, length : 1, return : 1.000
# Episode : 1118, length : 2, return : 1.000
# Episode : 1119, length : 2, return : -1.000
# Episode : 1120, length : 1, return : -1.000
# Episode : 1121, length : 1, return : -1.000
# Episode : 1122, length : 1, return : -1.000
# Episode : 1123, length : 2, return : 1.000
# Episode : 1124, length : 1, return : -1.000
# Episode : 1125, length : 1, return : -1.000
# Episode : 1126, length : 1, return : -1.000
# Episode : 1127, length : 1, return : -1.000
# ...
# Episode : 9634, length : 1, return : 1.000
# Episode : 9635, length : 1, return : -1.000
# Episode : 9636, length : 2, return : -1.000
# Episode : 9637, length : 2, return : -1.000
# Episode : 9638, length : 1, return : -1.000
# Episode : 9639, length : 2, return : 1.000
# Episode : 9640, length : 2, return : -1.000
# Episode : 9641, length : 1, return : 1.000
# Episode : 9642, length : 1, return : 0.000
# Episode : 9643, length : 2, return : -1.000
# Episode : 9644, length : 1, return : -1.000
# Episode : 9645, length : 1, return : 1.000
# Episode : 9646, length : 1, return : 1.000
# Episode : 9647, length : 1, return : 1.000
# Episode : 9648, length : 1, return : 1.000
# Episode : 9649, length : 2, return : 1.000
# Episode : 9650, length : 1, return : 1.000
# Episode : 9651, length : 3, return : -1.000
# Episode : 9652, length : 1, return : -1.000
# Episode : 9653, length : 2, return : 0.000
# Episode : 9654, length : 2, return : -1.000
# Episode : 9655, length : 1, return : 1.000
# Episode : 9656, length : 1, return : 1.000
# Episode : 9657, length : 1, return : -1.000
# Episode : 9658, length : 1, return : -1.000
# Episode : 9659, length : 1, return : -1.000
# Episode : 9660, length : 1, return : 1.000
# Episode : 9661, length : 4, return : 1.000
# Episode : 9662, length : 1, return : 1.000
# Episode : 9663, length : 1, return : 1.000
# Episode : 9664, length : 1, return : -1.000
# Episode : 9665, length : 2, return : 1.000
# Episode : 9666, length : 1, return : -1.000
# Episode : 9667, length : 1, return : 1.000
# Episode : 9668, length : 1, return : -1.000
# Episode : 9669, length : 1, return : 1.000
# Episode : 9670, length : 2, return : -1.000
# Episode : 9671, length : 3, return : 0.000
# Episode : 9672, length : 1, return : 0.000
# Episode : 9673, length : 3, return : -1.000
# Episode : 9674, length : 1, return : -1.000
# Episode : 9675, length : 1, return : 1.000
# Episode : 9676, length : 1, return : 1.000
# Episode : 9677, length : 2, return : -1.000
# Episode : 9678, length : 2, return : 1.000
# Episode : 9679, length : 2, return : 1.000
# Episode : 9680, length : 1, return : 1.000
# Episode : 9681, length : 1, return : -1.000
# Episode : 9682, length : 1, return : 1.000
# Episode : 9683, length : 4, return : -1.000
# Episode : 9684, length : 2, return : 1.000
# Episode : 9685, length : 2, return : -1.000
# Episode : 9686, length : 1, return : -1.000
# Episode : 9687, length : 2, return : -1.000
# Episode : 9688, length : 1, return : -1.000
# Episode : 9689, length : 1, return : -1.000
# Episode : 9690, length : 2, return : 1.000
# Episode : 9691, length : 2, return : 1.000
# Episode : 9692, length : 1, return : -1.000
# Episode : 9693, length : 1, return : -1.000
# Episode : 9694, length : 1, return : -1.000
# Episode : 9695, length : 2, return : -1.000
# Episode : 9696, length : 1, return : -1.000
# Episode : 9697, length : 1, return : -1.000
# Episode : 9698, length : 2, return : 0.000
# Episode : 9699, length : 1, return : 1.000
# Episode : 9700, length : 2, return : 1.000
# Episode : 9701, length : 1, return : -1.000
# Episode : 9702, length : 2, return : 1.000
# Episode : 9703, length : 2, return : 0.000
# Episode : 9704, length : 1, return : 1.000
# Episode : 9705, length : 1, return : 1.000
# Episode : 9706, length : 2, return : 1.000
# Episode : 9707, length : 2, return : -1.000
# Episode : 9708, length : 1, return : 1.000
# Episode : 9709, length : 1, return : -1.000
# Episode : 9710, length : 2, return : -1.000
# Episode : 9711, length : 4, return : 1.000
# Episode : 9712, length : 1, return : -1.000
# Episode : 9713, length : 1, return : 1.000
# Episode : 9714, length : 1, return : 0.000
# Episode : 9715, length : 1, return : -1.000
# Episode : 9716, length : 1, return : -1.000
# Episode : 9717, length : 1, return : -1.000
# Episode : 9718, length : 3, return : 1.000
# Episode : 9719, length : 3, return : -1.000
# Episode : 9720, length : 1, return : -1.000
# Episode : 9721, length : 2, return : 1.000
# Episode : 9722, length : 1, return : 1.000
# Episode : 9723, length : 4, return : 1.000
# Episode : 9724, length : 2, return : 1.000
# Episode : 9725, length : 1, return : -1.000
# Episode : 9726, length : 2, return : 1.000
# Episode : 9727, length : 2, return : 1.000
# Episode : 9728, length : 2, return : 1.000
# Episode : 9729, length : 1, return : -1.000
# Episode : 9730, length : 3, return : 1.000
# Episode : 9731, length : 1, return : -1.000
# Episode : 9732, length : 2, return : 1.000
# Episode : 9733, length : 1, return : -1.000
# Episode : 9734, length : 1, return : -1.000
# Episode : 9735, length : 1, return : -1.000
# Episode : 9736, length : 2, return : -1.000
# Episode : 9737, length : 2, return : -1.000
# Episode : 9738, length : 1, return : 1.000
# Episode : 9739, length : 1, return : 1.000
# Episode : 9740, length : 2, return : -1.000
# Episode : 9741, length : 1, return : -1.000
# Episode : 9742, length : 1, return : -1.000
# Episode : 9743, length : 1, return : -1.000
# Episode : 9744, length : 1, return : -1.000
# Episode : 9745, length : 2, return : -1.000
# Episode : 9746, length : 1, return : 1.000
# Episode : 9747, length : 2, return : 1.000
# Episode : 9748, length : 2, return : 1.000
# Episode : 9749, length : 1, return : -1.000
# Episode : 9750, length : 3, return : -1.000
# Episode : 9751, length : 1, return : -1.000
# Episode : 9752, length : 1, return : -1.000
# Episode : 9753, length : 2, return : 1.000
# Episode : 9754, length : 1, return : 1.000
# Episode : 9755, length : 2, return : 0.000
# Episode : 9756, length : 1, return : 1.000
# Episode : 9757, length : 1, return : 1.000
# Episode : 9758, length : 1, return : 1.000
# Episode : 9759, length : 2, return : 1.000
# Episode : 9760, length : 1, return : -1.000
# Episode : 9761, length : 2, return : -1.000
# Episode : 9762, length : 1, return : -1.000
# Episode : 9763, length : 1, return : -1.000
# Episode : 9764, length : 1, return : 1.000
# Episode : 9765, length : 1, return : -1.000
# Episode : 9766, length : 2, return : -1.000
# Episode : 9767, length : 1, return : 0.000
# Episode : 9768, length : 1, return : 1.000
# Episode : 9769, length : 1, return : 1.000
# Episode : 9770, length : 1, return : -1.000
# Episode : 9771, length : 2, return : -1.000
# Episode : 9772, length : 1, return : 1.000
# Episode : 9773, length : 2, return : -1.000
# Episode : 9774, length : 2, return : 1.000
# Episode : 9775, length : 1, return : -1.000
# Episode : 9776, length : 2, return : 1.000
# Episode : 9777, length : 1, return : 1.000
# Episode : 9778, length : 2, return : 0.000
# Episode : 9779, length : 2, return : 1.000
# Episode : 9780, length : 1, return : 1.000
# Episode : 9781, length : 1, return : -1.000
# Episode : 9782, length : 1, return : 0.000
# Episode : 9783, length : 1, return : 1.000
# Episode : 9784, length : 1, return : -1.000
# Episode : 9785, length : 1, return : 1.000
# Episode : 9786, length : 2, return : -1.000
# Episode : 9787, length : 1, return : -1.000
# Episode : 9788, length : 1, return : 1.000
# Episode : 9789, length : 1, return : -1.000
# Episode : 9790, length : 2, return : 1.000
# Episode : 9791, length : 3, return : 0.000
# Episode : 9792, length : 1, return : 1.000
# Episode : 9793, length : 1, return : 1.000
# Episode : 9794, length : 1, return : -1.000
# Episode : 9795, length : 2, return : 0.000
# Episode : 9796, length : 1, return : -1.000
# Episode : 9797, length : 1, return : -1.000
# Episode : 9798, length : 2, return : -1.000
# Episode : 9799, length : 1, return : 1.000
# Episode : 9800, length : 1, return : 1.000
# Episode : 9801, length : 2, return : -1.000
# Episode : 9802, length : 1, return : -1.000
# Episode : 9803, length : 1, return : 1.000
# Episode : 9804, length : 2, return : -1.000
# Episode : 9805, length : 2, return : 1.000
# Episode : 9806, length : 2, return : -1.000
# Episode : 9807, length : 2, return : -1.000
# Episode : 9808, length : 1, return : -1.000
# Episode : 9809, length : 2, return : 1.000
# Episode : 9810, length : 2, return : 1.000
# Episode : 9811, length : 1, return : -1.000
# Episode : 9812, length : 1, return : -1.000
# Episode : 9813, length : 1, return : -1.000
# Episode : 9814, length : 1, return : -1.000
# Episode : 9815, length : 1, return : 1.000
# Episode : 9816, length : 3, return : -1.000
# Episode : 9817, length : 1, return : -1.000
# Episode : 9818, length : 1, return : -1.000
# Episode : 9819, length : 1, return : 1.000
# Episode : 9820, length : 1, return : -1.000
# Episode : 9821, length : 1, return : -1.000
# Episode : 9822, length : 3, return : 1.000
# Episode : 9823, length : 1, return : -1.000
# Episode : 9824, length : 1, return : 1.000
# Episode : 9825, length : 3, return : -1.000
# Episode : 9826, length : 1, return : 1.000
# Episode : 9827, length : 1, return : 1.000
# Episode : 9828, length : 1, return : 0.000
# Episode : 9829, length : 1, return : -1.000
# Episode : 9830, length : 1, return : -1.000
# Episode : 9831, length : 3, return : 1.000
# Episode : 9832, length : 1, return : -1.000
# Episode : 9833, length : 1, return : -1.000
# Episode : 9834, length : 1, return : -1.000
# Episode : 9835, length : 1, return : 0.000
# Episode : 9836, length : 2, return : 1.000
# Episode : 9837, length : 2, return : 1.000
# Episode : 9838, length : 1, return : 1.000
# Episode : 9839, length : 1, return : -1.000
# Episode : 9840, length : 1, return : 1.000
# Episode : 9841, length : 1, return : -1.000
# Episode : 9842, length : 2, return : 1.000
# Episode : 9843, length : 1, return : -1.000
# Episode : 9844, length : 1, return : -1.000
# Episode : 9845, length : 1, return : -1.000
# Episode : 9846, length : 2, return : -1.000
# Episode : 9847, length : 1, return : -1.000
# Episode : 9848, length : 1, return : -1.000
# Episode : 9849, length : 1, return : -1.000
# Episode : 9850, length : 1, return : -1.000
# Episode : 9851, length : 1, return : -1.000
# Episode : 9852, length : 1, return : -1.000
# Episode : 9853, length : 1, return : -1.000
# Episode : 9854, length : 1, return : 0.000
# Episode : 9855, length : 2, return : 1.000
# Episode : 9856, length : 2, return : -1.000
# Episode : 9857, length : 1, return : -1.000
# Episode : 9858, length : 1, return : -1.000
# Episode : 9859, length : 2, return : 0.000
# Episode : 9860, length : 2, return : -1.000
# Episode : 9861, length : 1, return : 1.000
# Episode : 9862, length : 1, return : -1.000
# Episode : 9863, length : 2, return : -1.000
# Episode : 9864, length : 1, return : -1.000
# Episode : 9865, length : 2, return : 1.000
# Episode : 9866, length : 1, return : -1.000
# Episode : 9867, length : 1, return : 0.000
# Episode : 9868, length : 1, return : 1.000
# Episode : 9869, length : 4, return : 1.000
# Episode : 9870, length : 1, return : 1.000
# Episode : 9871, length : 1, return : -1.000
# Episode : 9872, length : 1, return : -1.000
# Episode : 9873, length : 1, return : -1.000
# Episode : 9874, length : 1, return : 0.000
# Episode : 9875, length : 1, return : -1.000
# Episode : 9876, length : 1, return : 0.000
# Episode : 9877, length : 1, return : -1.000
# Episode : 9878, length : 1, return : -1.000
# Episode : 9879, length : 1, return : -1.000
# Episode : 9880, length : 3, return : -1.000
# Episode : 9881, length : 1, return : -1.000
# Episode : 9882, length : 2, return : 1.000
# Episode : 9883, length : 1, return : 1.000
# Episode : 9884, length : 1, return : -1.000
# Episode : 9885, length : 1, return : -1.000
# Episode : 9886, length : 1, return : 0.000
# Episode : 9887, length : 1, return : 1.000
# Episode : 9888, length : 2, return : -1.000
# Episode : 9889, length : 2, return : -1.000
# Episode : 9890, length : 1, return : -1.000
# Episode : 9891, length : 1, return : -1.000
# Episode : 9892, length : 1, return : 1.000
# Episode : 9893, length : 1, return : -1.000
# Episode : 9894, length : 1, return : -1.000
# Episode : 9895, length : 1, return : 1.000
# Episode : 9896, length : 3, return : -1.000
# Episode : 9897, length : 2, return : 0.000
# Episode : 9898, length : 1, return : -1.000
# Episode : 9899, length : 2, return : -1.000
# Episode : 9900, length : 2, return : -1.000
# Episode : 9901, length : 1, return : 1.000
# Episode : 9902, length : 2, return : 1.000
# Episode : 9903, length : 1, return : 1.000
# Episode : 9904, length : 2, return : -1.000
# Episode : 9905, length : 2, return : -1.000
# Episode : 9906, length : 1, return : 1.000
# Episode : 9907, length : 1, return : 1.000
# Episode : 9908, length : 1, return : -1.000
# Episode : 9909, length : 1, return : -1.000
# Episode : 9910, length : 1, return : 1.000
# Episode : 9911, length : 1, return : -1.000
# Episode : 9912, length : 2, return : -1.000
# Episode : 9913, length : 2, return : 1.000
# Episode : 9914, length : 1, return : -1.000
# Episode : 9915, length : 2, return : 1.000
# Episode : 9916, length : 1, return : -1.000
# Episode : 9917, length : 1, return : 1.000
# Episode : 9918, length : 1, return : 1.000
# Episode : 9919, length : 1, return : -1.000
# Episode : 9920, length : 2, return : 1.000
# Episode : 9921, length : 1, return : -1.000
# Episode : 9922, length : 1, return : 1.000
# Episode : 9923, length : 1, return : -1.000
# Episode : 9924, length : 1, return : -1.000
# Episode : 9925, length : 1, return : -1.000
# Episode : 9926, length : 1, return : -1.000
# Episode : 9927, length : 2, return : -1.000
# Episode : 9928, length : 1, return : -1.000
# Episode : 9929, length : 2, return : 1.000
# Episode : 9930, length : 2, return : 1.000
# Episode : 9931, length : 2, return : -1.000
# Episode : 9932, length : 1, return : -1.000
# Episode : 9933, length : 1, return : -1.000
# Episode : 9934, length : 3, return : -1.000
# Episode : 9935, length : 1, return : -1.000
# Episode : 9936, length : 1, return : 1.000
# Episode : 9937, length : 1, return : -1.000
# Episode : 9938, length : 2, return : 1.000
# Episode : 9939, length : 1, return : 1.000
# Episode : 9940, length : 1, return : -1.000
# Episode : 9941, length : 1, return : -1.000
# Episode : 9942, length : 2, return : -1.000
# Episode : 9943, length : 1, return : 1.000
# Episode : 9944, length : 1, return : 0.000
# Episode : 9945, length : 4, return : -1.000
# Episode : 9946, length : 1, return : -1.000
# Episode : 9947, length : 1, return : 0.000
# Episode : 9948, length : 1, return : -1.000
# Episode : 9949, length : 1, return : -1.000
# Episode : 9950, length : 1, return : -1.000
# Episode : 9951, length : 2, return : -1.000
# Episode : 9952, length : 2, return : -1.000
# Episode : 9953, length : 2, return : -1.000
# Episode : 9954, length : 1, return : 1.000
# Episode : 9955, length : 1, return : -1.000
# Episode : 9956, length : 1, return : -1.000
# Episode : 9957, length : 1, return : 0.000
# Episode : 9958, length : 1, return : -1.000
# Episode : 9959, length : 1, return : -1.000
# Episode : 9960, length : 1, return : 1.000
# Episode : 9961, length : 2, return : -1.000
# Episode : 9962, length : 1, return : -1.000
# Episode : 9963, length : 1, return : -1.000
# Episode : 9964, length : 1, return : 1.000
# Episode : 9965, length : 3, return : -1.000
# Episode : 9966, length : 2, return : 1.000
# Episode : 9967, length : 1, return : 1.000
# Episode : 9968, length : 1, return : -1.000
# Episode : 9969, length : 1, return : 1.000
# Episode : 9970, length : 2, return : 1.000
# Episode : 9971, length : 2, return : 1.000
# Episode : 9972, length : 2, return : 0.000
# Episode : 9973, length : 1, return : 1.000
# Episode : 9974, length : 1, return : 0.000
# Episode : 9975, length : 1, return : -1.000
# Episode : 9976, length : 2, return : -1.000
# Episode : 9977, length : 3, return : -1.000
# Episode : 9978, length : 1, return : -1.000
# Episode : 9979, length : 2, return : -1.000
# Episode : 9980, length : 1, return : -1.000
# Episode : 9981, length : 1, return : -1.000
# Episode : 9982, length : 1, return : -1.000
# Episode : 9983, length : 1, return : 1.000
# Episode : 9984, length : 1, return : 1.000
# Episode : 9985, length : 1, return : -1.000
# Episode : 9986, length : 1, return : 1.000
# Episode : 9987, length : 1, return : 1.000
# Episode : 9988, length : 2, return : -1.000
# Episode : 9989, length : 2, return : -1.000
# Episode : 9990, length : 1, return : -1.000
# Episode : 9991, length : 2, return : -1.000
# Episode : 9992, length : 2, return : 1.000
# Episode : 9993, length : 1, return : 1.000
# Episode : 9994, length : 1, return : 1.000
# Episode : 9995, length : 2, return : 1.000
# Episode : 9996, length : 1, return : -1.000
# Episode : 9997, length : 2, return : 1.000
# Episode : 9998, length : 1, return : -1.000
# Episode : 9999, length : 1, return : -1.000
# avg : -0.152, std : 0.954
# (-0.1517, 0.9538800291441268)

# %%
env = gym.make('Blackjack-v1', natural=False, sab=False, render_mode='human')
agent.test(env, n_episodes=10, verbose=True)
env.close()
# Out:
# 2025-03-31 22:48:47.122 python[4954:383214] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-31 22:48:47.122 python[4954:383214] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Episode : 0, length : 2, return : 1.000
# Episode : 1, length : 2, return : 1.000
# Episode : 2, length : 1, return : -1.000
# Episode : 3, length : 2, return : 1.000
# Episode : 4, length : 2, return : 1.000
# Episode : 5, length : 2, return : 1.000
# Episode : 6, length : 1, return : -1.000
# Episode : 7, length : 2, return : -1.000
# Episode : 8, length : 1, return : 1.000
# Episode : 9, length : 2, return : 1.000
# avg : 0.400, std : 0.917

# %% [markdown]
# ## Taxi

# %%
env = gym.make('Taxi-v3')
agent = TaxiQLearning(env, gamma=0.99)
agent.train(alpha=0.1, n_train=100000, print_iter=1000, decay_rate=1e-4)
# Out:
# Iteration : 0
# Epsilon   : 1.00000
#
#
# Iteration : 1000
# Epsilon   : 0.91435
#
#
# Iteration : 2000
# Epsilon   : 0.83686
#
#
# Iteration : 3000
# Epsilon   : 0.76674
#
#
# Iteration : 4000
# Epsilon   : 0.70329
#
#
# Iteration : 5000
# Epsilon   : 0.64588
#
#
# Iteration : 6000
# Epsilon   : 0.59393
#
#
# Iteration : 7000
# Epsilon   : 0.54693
#
#
# Iteration : 8000
# Epsilon   : 0.50440
#
#
# Iteration : 9000
# Epsilon   : 0.46591
#
#
# Iteration : 10000
# Epsilon   : 0.43109
#
#
# Iteration : 11000
# Epsilon   : 0.39958
#
#
# Iteration : 12000
# Epsilon   : 0.37107
#
#
# Iteration : 13000
# Epsilon   : 0.34528
#
#
# Iteration : 14000
# Epsilon   : 0.32194
#
#
# Iteration : 15000
# Epsilon   : 0.30082
#
#
# Iteration : 16000
# Epsilon   : 0.28171
#
#
# Iteration : 17000
# Epsilon   : 0.26442
#
#
# Iteration : 18000
# Epsilon   : 0.24877
#
#
# Iteration : 19000
# Epsilon   : 0.23461
#
#
# Iteration : 20000
# Epsilon   : 0.22180
#
#
# Iteration : 21000
# Epsilon   : 0.21021
#
#
# Iteration : 22000
# Epsilon   : 0.19972
#
#
# Iteration : 23000
# Epsilon   : 0.19023
#
#
# Iteration : 24000
# Epsilon   : 0.18165
#
#
# Iteration : 25000
# Epsilon   : 0.17388
#
#
# Iteration : 26000
# Epsilon   : 0.16685
#
#
# Iteration : 27000
# Epsilon   : 0.16048
#
#
# Iteration : 28000
# Epsilon   : 0.15473
#
#
# Iteration : 29000
# Epsilon   : 0.14952
#
#
# Iteration : 30000
# Epsilon   : 0.14481
#
#
# Iteration : 31000
# Epsilon   : 0.14054
#
#
# Iteration : 32000
# Epsilon   : 0.13669
#
#
# Iteration : 33000
# Epsilon   : 0.13319
#
#
# Iteration : 34000
# Epsilon   : 0.13004
#
#
# Iteration : 35000
# Epsilon   : 0.12718
#
#
# Iteration : 36000
# Epsilon   : 0.12459
#
#
# Iteration : 37000
# Epsilon   : 0.12225
#
#
# Iteration : 38000
# Epsilon   : 0.12013
#
#
# Iteration : 39000
# Epsilon   : 0.11822
#
#
# Iteration : 40000
# Epsilon   : 0.11648
#
#
# Iteration : 41000
# Epsilon   : 0.11492
#
#
# Iteration : 42000
# Epsilon   : 0.11350
#
#
# Iteration : 43000
# Epsilon   : 0.11221
#
#
# Iteration : 44000
# Epsilon   : 0.11105
#
#
# Iteration : 45000
# Epsilon   : 0.11000
#
#
# Iteration : 46000
# Epsilon   : 0.10905
#
#
# Iteration : 47000
# Epsilon   : 0.10819
#
#
# Iteration : 48000
# Epsilon   : 0.10741
#
#
# Iteration : 49000
# Epsilon   : 0.10670
#
#
# Iteration : 50000
# Epsilon   : 0.10606
#
#
# Iteration : 51000
# Epsilon   : 0.10549
#
#
# Iteration : 52000
# Epsilon   : 0.10496
#
#
# Iteration : 53000
# Epsilon   : 0.10449
#
#
# Iteration : 54000
# Epsilon   : 0.10406
#
#
# Iteration : 55000
# Epsilon   : 0.10368
#
#
# Iteration : 56000
# Epsilon   : 0.10333
#
#
# Iteration : 57000
# Epsilon   : 0.10301
#
#
# Iteration : 58000
# Epsilon   : 0.10272
#
#
# Iteration : 59000
# Epsilon   : 0.10247
#
#
# Iteration : 60000
# Epsilon   : 0.10223
#
#
# Iteration : 61000
# Epsilon   : 0.10202
#
#
# Iteration : 62000
# Epsilon   : 0.10183
#
#
# Iteration : 63000
# Epsilon   : 0.10165
#
#
# Iteration : 64000
# Epsilon   : 0.10150
#
#
# Iteration : 65000
# Epsilon   : 0.10135
#
#
# Iteration : 66000
# Epsilon   : 0.10122
#
#
# Iteration : 67000
# Epsilon   : 0.10111
#
#
# Iteration : 68000
# Epsilon   : 0.10100
#
#
# Iteration : 69000
# Epsilon   : 0.10091
#
#
# Iteration : 70000
# Epsilon   : 0.10082
#
#
# Iteration : 71000
# Epsilon   : 0.10074
#
#
# Iteration : 72000
# Epsilon   : 0.10067
#
#
# Iteration : 73000
# Epsilon   : 0.10061
#
#
# Iteration : 74000
# Epsilon   : 0.10055
#
#
# Iteration : 75000
# Epsilon   : 0.10050
#
#
# Iteration : 76000
# Epsilon   : 0.10045
#
#
# Iteration : 77000
# Epsilon   : 0.10041
#
#
# Iteration : 78000
# Epsilon   : 0.10037
#
#
# Iteration : 79000
# Epsilon   : 0.10033
#
#
# Iteration : 80000
# Epsilon   : 0.10030
#
#
# Iteration : 81000
# Epsilon   : 0.10027
#
#
# Iteration : 82000
# Epsilon   : 0.10025
#
#
# Iteration : 83000
# Epsilon   : 0.10022
#
#
# Iteration : 84000
# Epsilon   : 0.10020
#
#
# Iteration : 85000
# Epsilon   : 0.10018
#
#
# Iteration : 86000
# Epsilon   : 0.10017
#
#
# Iteration : 87000
# Epsilon   : 0.10015
#
#
# Iteration : 88000
# Epsilon   : 0.10014
#
#
# Iteration : 89000
# Epsilon   : 0.10012
#
#
# Iteration : 90000
# Epsilon   : 0.10011
#
#
# Iteration : 91000
# Epsilon   : 0.10010
#
#
# Iteration : 92000
# Epsilon   : 0.10009
#
#
# Iteration : 93000
# Epsilon   : 0.10008
#
#
# Iteration : 94000
# Epsilon   : 0.10007
#
#
# Iteration : 95000
# Epsilon   : 0.10007
#
#
# Iteration : 96000
# Epsilon   : 0.10006
#
#
# Iteration : 97000
# Epsilon   : 0.10006
#
#
# Iteration : 98000
# Epsilon   : 0.10005
#
#
# Iteration : 99000
# Epsilon   : 0.10005

# %%
agent.test(env, n_episodes=100, verbose=True)
# Out:
# Episode : 0, length : 8, return : 13.000
# Episode : 1, length : 13, return : 8.000
# Episode : 2, length : 11, return : 10.000
# Episode : 3, length : 12, return : 9.000
# Episode : 4, length : 16, return : 5.000
# Episode : 5, length : 15, return : 6.000
# Episode : 6, length : 8, return : 13.000
# Episode : 7, length : 7, return : 14.000
# Episode : 8, length : 15, return : 6.000
# Episode : 9, length : 12, return : 9.000
# Episode : 10, length : 6, return : 15.000
# Episode : 11, length : 13, return : 8.000
# Episode : 12, length : 12, return : 9.000
# Episode : 13, length : 14, return : 7.000
# Episode : 14, length : 16, return : 5.000
# Episode : 15, length : 9, return : 12.000
# Episode : 16, length : 11, return : 10.000
# Episode : 17, length : 11, return : 10.000
# Episode : 18, length : 10, return : 11.000
# Episode : 19, length : 10, return : 11.000
# Episode : 20, length : 9, return : 12.000
# Episode : 21, length : 15, return : 6.000
# Episode : 22, length : 15, return : 6.000
# Episode : 23, length : 12, return : 9.000
# Episode : 24, length : 12, return : 9.000
# Episode : 25, length : 10, return : 11.000
# Episode : 26, length : 16, return : 5.000
# Episode : 27, length : 11, return : 10.000
# Episode : 28, length : 14, return : 7.000
# Episode : 29, length : 13, return : 8.000
# Episode : 30, length : 14, return : 7.000
# Episode : 31, length : 9, return : 12.000
# Episode : 32, length : 12, return : 9.000
# Episode : 33, length : 14, return : 7.000
# Episode : 34, length : 15, return : 6.000
# Episode : 35, length : 18, return : 3.000
# Episode : 36, length : 12, return : 9.000
# Episode : 37, length : 13, return : 8.000
# Episode : 38, length : 17, return : 4.000
# Episode : 39, length : 14, return : 7.000
# Episode : 40, length : 8, return : 13.000
# Episode : 41, length : 12, return : 9.000
# Episode : 42, length : 16, return : 5.000
# Episode : 43, length : 13, return : 8.000
# Episode : 44, length : 14, return : 7.000
# Episode : 45, length : 13, return : 8.000
# Episode : 46, length : 14, return : 7.000
# Episode : 47, length : 15, return : 6.000
# Episode : 48, length : 9, return : 12.000
# Episode : 49, length : 12, return : 9.000
# Episode : 50, length : 11, return : 10.000
# Episode : 51, length : 12, return : 9.000
# Episode : 52, length : 10, return : 11.000
# Episode : 53, length : 13, return : 8.000
# Episode : 54, length : 9, return : 12.000
# Episode : 55, length : 18, return : 3.000
# Episode : 56, length : 11, return : 10.000
# Episode : 57, length : 15, return : 6.000
# Episode : 58, length : 16, return : 5.000
# Episode : 59, length : 11, return : 10.000
# Episode : 60, length : 13, return : 8.000
# Episode : 61, length : 13, return : 8.000
# Episode : 62, length : 13, return : 8.000
# Episode : 63, length : 9, return : 12.000
# Episode : 64, length : 14, return : 7.000
# Episode : 65, length : 11, return : 10.000
# Episode : 66, length : 16, return : 5.000
# Episode : 67, length : 15, return : 6.000
# Episode : 68, length : 12, return : 9.000
# Episode : 69, length : 16, return : 5.000
# Episode : 70, length : 15, return : 6.000
# Episode : 71, length : 13, return : 8.000
# Episode : 72, length : 12, return : 9.000
# Episode : 73, length : 13, return : 8.000
# Episode : 74, length : 12, return : 9.000
# Episode : 75, length : 14, return : 7.000
# Episode : 76, length : 16, return : 5.000
# Episode : 77, length : 12, return : 9.000
# Episode : 78, length : 12, return : 9.000
# Episode : 79, length : 13, return : 8.000
# Episode : 80, length : 13, return : 8.000
# Episode : 81, length : 15, return : 6.000
# Episode : 82, length : 15, return : 6.000
# Episode : 83, length : 14, return : 7.000
# Episode : 84, length : 11, return : 10.000
# Episode : 85, length : 12, return : 9.000
# Episode : 86, length : 8, return : 13.000
# Episode : 87, length : 15, return : 6.000
# Episode : 88, length : 10, return : 11.000
# Episode : 89, length : 14, return : 7.000
# Episode : 90, length : 15, return : 6.000
# Episode : 91, length : 17, return : 4.000
# Episode : 92, length : 11, return : 10.000
# Episode : 93, length : 13, return : 8.000
# Episode : 94, length : 9, return : 12.000
# Episode : 95, length : 15, return : 6.000
# Episode : 96, length : 7, return : 14.000
# Episode : 97, length : 15, return : 6.000
# Episode : 98, length : 14, return : 7.000
# Episode : 99, length : 18, return : 3.000
# avg : 8.290, std : 2.601
# (8.29, 2.601134367924887)

# %%
env = gym.make('Taxi-v3', render_mode='human')
agent.test(env, n_episodes=10, verbose=True)
env.close()
# Out:
# Episode : 0, length : 17, return : 4.000
# Episode : 1, length : 18, return : 3.000
# Episode : 2, length : 14, return : 7.000
# Episode : 3, length : 16, return : 5.000
# Episode : 4, length : 13, return : 8.000
# Episode : 5, length : 13, return : 8.000
# Episode : 6, length : 15, return : 6.000
# Episode : 7, length : 16, return : 5.000
# Episode : 8, length : 14, return : 7.000
# Episode : 9, length : 8, return : 13.000
# avg : 6.600, std : 2.653
